# %% [markdown]
# # P4Lang Tutorials of FABRIC
#
# This notebook walks the user through setting up a FABRIC eperiment that is suitiable for completing the P4 tutorials created by [P4Lang](https://github.com/p4lang/tutorials). The tutorials were origianlly designed to use a mininet topology. This example replaces the mininet topology with a FABRIC experiemnt topology that may span multiple sites across the FABRIC testbed.
#
# Additional resources:
# - [FABRIC Knowledge Base](https://learn.fabric-testbed.net/)
# - [FABRIC Forums](https://learn.fabric-testbed.net/forums/)
# - [P4Lang Tutorials](https://github.com/p4lang/tutorials)
# - [P4Lang YouTube Presentations](https://www.youtube.com/channel/UCOQAFkDKucJWr-KafdJsdIQ)

# %% [markdown]
# ## Basic FABRIC Slice Configuration

# %%
import json
import traceback
# from fabrictestbed_extensions.fablib.fablib import fablib
from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

fablib = fablib_manager()

# %%
try:
    print(f"{fablib.list_sites()}")
except Exception as e:
    print(f"Exception: {e}")
# Out:
# <style type="text/css">
# #T_dd469 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_dd469 th {
#   text-align: left;
# }
# #T_dd469 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_dd469 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_dd469 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_dd469_row0_col0, #T_dd469_row0_col1, #T_dd469_row0_col2, #T_dd469_row0_col3, #T_dd469_row0_col4, #T_dd469_row0_col5, #T_dd469_row0_col6, #T_dd469_row0_col7, #T_dd469_row0_col8, #T_dd469_row0_col9, #T_dd469_row0_col10, #T_dd469_row0_col11, #T_dd469_row0_col12, #T_dd469_row0_col13, #T_dd469_row0_col14, #T_dd469_row0_col15, #T_dd469_row0_col16, #T_dd469_row0_col17, #T_dd469_row0_col18, #T_dd469_row0_col19, #T_dd469_row0_col20, #T_dd469_row0_col21, #T_dd469_row0_col22, #T_dd469_row0_col23, #T_dd469_row0_col24, #T_dd469_row0_col25, #T_dd469_row0_col26, #T_dd469_row0_col27, #T_dd469_row0_col28, #T_dd469_row0_col29, #T_dd469_row0_col30, #T_dd469_row0_col31, #T_dd469_row1_col0, #T_dd469_row1_col1, #T_dd469_row1_col2, #T_dd469_row1_col3, #T_dd469_row1_col4, #T_dd469_row1_col5, #T_dd469_row1_col6, #T_dd469_row1_col7, #T_dd469_row1_col8, #T_dd469_row1_col9, #T_dd469_row1_col10, #T_dd469_row1_col11, #T_dd469_row1_col12, #T_dd469_row1_col13, #T_dd469_row1_col14, #T_dd469_row1_col15, #T_dd469_row1_col16, #T_dd469_row1_col17, #T_dd469_row1_col18, #T_dd469_row1_col19, #T_dd469_row1_col20, #T_dd469_row1_col21, #T_dd469_row1_col22, #T_dd469_row1_col23, #T_dd469_row1_col24, #T_dd469_row1_col25, #T_dd469_row1_col26, #T_dd469_row1_col27, #T_dd469_row1_col28, #T_dd469_row1_col29, #T_dd469_row1_col30, #T_dd469_row1_col31, #T_dd469_row2_col0, #T_dd469_row2_col1, #T_dd469_row2_col2, #T_dd469_row2_col3, #T_dd469_row2_col4, #T_dd469_row2_col5, #T_dd469_row2_col6, #T_dd469_row2_col7, #T_dd469_row2_col8, #T_dd469_row2_col9, #T_dd469_row2_col10, #T_dd469_row2_col11, #T_dd469_row2_col12, #T_dd469_row2_col13, #T_dd469_row2_col14, #T_dd469_row2_col15, #T_dd469_row2_col16, #T_dd469_row2_col17, #T_dd469_row2_col18, #T_dd469_row2_col19, #T_dd469_row2_col20, #T_dd469_row2_col21, #T_dd469_row2_col22, #T_dd469_row2_col23, #T_dd469_row2_col24, #T_dd469_row2_col25, #T_dd469_row2_col26, #T_dd469_row2_col27, #T_dd469_row2_col28, #T_dd469_row2_col29, #T_dd469_row2_col30, #T_dd469_row2_col31, #T_dd469_row3_col0, #T_dd469_row3_col1, #T_dd469_row3_col2, #T_dd469_row3_col3, #T_dd469_row3_col4, #T_dd469_row3_col5, #T_dd469_row3_col6, #T_dd469_row3_col7, #T_dd469_row3_col8, #T_dd469_row3_col9, #T_dd469_row3_col10, #T_dd469_row3_col11, #T_dd469_row3_col12, #T_dd469_row3_col13, #T_dd469_row3_col14, #T_dd469_row3_col15, #T_dd469_row3_col16, #T_dd469_row3_col17, #T_dd469_row3_col18, #T_dd469_row3_col19, #T_dd469_row3_col20, #T_dd469_row3_col21, #T_dd469_row3_col22, #T_dd469_row3_col23, #T_dd469_row3_col24, #T_dd469_row3_col25, #T_dd469_row3_col26, #T_dd469_row3_col27, #T_dd469_row3_col28, #T_dd469_row3_col29, #T_dd469_row3_col30, #T_dd469_row3_col31, #T_dd469_row4_col0, #T_dd469_row4_col1, #T_dd469_row4_col2, #T_dd469_row4_col3, #T_dd469_row4_col4, #T_dd469_row4_col5, #T_dd469_row4_col6, #T_dd469_row4_col7, #T_dd469_row4_col8, #T_dd469_row4_col9, #T_dd469_row4_col10, #T_dd469_row4_col11, #T_dd469_row4_col12, #T_dd469_row4_col13, #T_dd469_row4_col14, #T_dd469_row4_col15, #T_dd469_row4_col16, #T_dd469_row4_col17, #T_dd469_row4_col18, #T_dd469_row4_col19, #T_dd469_row4_col20, #T_dd469_row4_col21, #T_dd469_row4_col22, #T_dd469_row4_col23, #T_dd469_row4_col24, #T_dd469_row4_col25, #T_dd469_row4_col26, #T_dd469_row4_col27, #T_dd469_row4_col28, #T_dd469_row4_col29, #T_dd469_row4_col30, #T_dd469_row4_col31, #T_dd469_row5_col0, #T_dd469_row5_col1, #T_dd469_row5_col2, #T_dd469_row5_col3, #T_dd469_row5_col4, #T_dd469_row5_col5, #T_dd469_row5_col6, #T_dd469_row5_col7, #T_dd469_row5_col8, #T_dd469_row5_col9, #T_dd469_row5_col10, #T_dd469_row5_col11, #T_dd469_row5_col12, #T_dd469_row5_col13, #T_dd469_row5_col14, #T_dd469_row5_col15, #T_dd469_row5_col16, #T_dd469_row5_col17, #T_dd469_row5_col18, #T_dd469_row5_col19, #T_dd469_row5_col20, #T_dd469_row5_col21, #T_dd469_row5_col22, #T_dd469_row5_col23, #T_dd469_row5_col24, #T_dd469_row5_col25, #T_dd469_row5_col26, #T_dd469_row5_col27, #T_dd469_row5_col28, #T_dd469_row5_col29, #T_dd469_row5_col30, #T_dd469_row5_col31, #T_dd469_row6_col0, #T_dd469 ...
# <pandas.io.formats.style.Styler object at 0x7f2c5348ba60>

# %% [markdown]
# ## Configure Slice Parameters
#
# This section builds the experiment slice
#
# <img src="figs/fabric_slice.png" width="800"/>

# %%
from ipaddress import ip_address, IPv4Address, IPv6Address, IPv4Network, IPv6Network

# Slice 
slice_name = 'CNERT 2'

# [site1,site2,site3] = fablib.get_random_sites(count=3)
site1 = site2 = site3 = 'TACC'
print(f"Sites: {site1},{site2},{site3}")


# Switches
s1_name = "s1"
s2_name = "s2"
s3_name = "s3"

switch_cores = 2
switch_ram = 8
switch_disk = 100

# Hosts
h1_name = "h1"
h11_name = "h11"
h2_name = "h2"
h22_name = "h22"
h3_name = "h3"

h1_subnet=IPv4Network('10.0.0.0/16')
h1_addr=IPv4Address('10.0.1.1')
h11_addr=IPv4Address('10.0.1.11')

h2_subnet=h1_subnet #IPv4Network('10.0.0.0/16')
h2_addr=IPv4Address('10.0.2.2')
h22_addr=IPv4Address('10.0.2.22')

h3_addr=IPv4Address('10.0.3.3')

host_cores = 2
host_ram = 8
host_disk = 20

net_h1_name = 'net_h1'
net_h11_name = 'net_h11'
net_h2_name = 'net_h2'
net_h22_name = 'net_h22'
net_h3_name = 'net_h3'

net_s1_s2_name = 'net_s1_s2'
net_s2_s3_name = 'net_s2_s3'
net_s1_s3_name = 'net_s1_s3'

s1_iface_h1,s1_iface_h11,s1_iface_to_s2,s1_iface_to_s3 = "s1_iface_h1","s1_iface_h11","s1_iface_to_s2","s1_iface_to_s3"  
s2_iface_h2,s2_iface_h22,s2_iface_to_s1,s2_iface_to_s3 = "s2_iface_h2","s2_iface_h22","s2_iface_to_s1","s2_iface_to_s3" 
s3_iface_h3, s3_iface_to_s1,s3_iface_to_s2 = "s3_iface_h3", "s3_iface_to_s1","s3_iface_to_s2"

# All node properties
image = 'default_ubuntu_20'
# Out:
# Sites: TACC,TACC,TACC

# %% [markdown]
# ### Create the Slice

# %%
import datetime

try:
    #Create Slice
    slice = fablib.new_slice(name=slice_name)
    
    def addSwitchNIC(nodeName,site,ifaceNames):
        node = slice.add_node(name=nodeName, site=site,  image=image, cores=switch_cores, ram=switch_ram, disk=switch_disk)
        ifaceObj = {}
        for name in ifaceNames:
            iface =  node.add_component(model='NIC_Basic', name=name).get_interfaces()[0]
            ifaceObj[name] = iface
        return node, ifaceObj
    
    # Add switch node s1
    s1, s1_ifaces = addSwitchNIC(s1_name,site1,[s1_iface_h1,s1_iface_h11,s1_iface_to_s2,s1_iface_to_s3])

    # Add switch node s2
    s2, s2_ifaces = addSwitchNIC(s2_name,site2,[s2_iface_h2,s2_iface_h22,s2_iface_to_s1,s2_iface_to_s3])
    
    # Add switch node s3
    s3, s3_ifaces = addSwitchNIC(s3_name,site3,[s3_iface_h3, s3_iface_to_s1,s3_iface_to_s2])
    
    def addHostNIC(nodeName,componentName,site):
        node = slice.add_node(name=nodeName, site=site, image=image, cores=host_cores, ram=host_ram, disk=host_disk)
        iface = node.add_component(model='NIC_Basic', name=componentName).get_interfaces()[0]
        return node,iface
    
    # Add host node h1
    h1,h1_iface = addHostNIC(h1_name,"h1_nic",site1)

    # Add host node h11
    h11 , h11_iface = addHostNIC(h11_name,"h11_nic",site1)
    
    # Add host node h2
    h2, h2_iface = addHostNIC(h2_name,"h2_nic",site2)
    
    # Add host node h22
    h22, h22_iface = addHostNIC(h22_name,"h22_nic",site2)
    
    # Add host node h3
    h3, h3_iface = addHostNIC(h3_name,"h3_nic",site2)
    
    #Add swtich networks
    switch_net1 = slice.add_l2network(name=net_s1_s2_name, interfaces=[s1_ifaces[s1_iface_to_s2], s2_ifaces[s2_iface_to_s1]])
    swtich_net2 = slice.add_l2network(name=net_s2_s3_name, interfaces=[s2_ifaces[s2_iface_to_s3], s3_ifaces[s3_iface_to_s2]])
    swtich_net3 = slice.add_l2network(name=net_s1_s3_name, interfaces=[s3_ifaces[s3_iface_to_s1], s1_ifaces[s1_iface_to_s3]])

    #Add host networks 
    host_net1 = slice.add_l2network(name=net_h1_name, interfaces=[s1_ifaces[s1_iface_h1], h1_iface])
    host_net11 = slice.add_l2network(name=net_h11_name, interfaces=[s1_ifaces[s1_iface_h11], h11_iface])
    host_net2 = slice.add_l2network(name=net_h2_name, interfaces=[s2_ifaces[s2_iface_h2], h2_iface])
    host_net22 = slice.add_l2network(name=net_h22_name, interfaces=[s2_ifaces[s2_iface_h22], h22_iface])
    host_net3 = slice.add_l2network(name=net_h3_name, interfaces=[s3_ifaces[s3_iface_h3], h3_iface])
    #Submit Slice Request
    slice.submit() 
except Exception as e:
    print(f"Error: {e}")
    traceback.print_exc()
# Out:
# Retry: 3, Time: 341 sec
# <style type="text/css">
# #T_5b882 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_5b882 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_5b882 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_5b882_row0_col0, #T_5b882_row0_col1, #T_5b882_row1_col0, #T_5b882_row1_col1, #T_5b882_row2_col0, #T_5b882_row2_col1, #T_5b882_row3_col0, #T_5b882_row3_col1, #T_5b882_row4_col0, #T_5b882_row4_col1, #T_5b882_row5_col0 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# #T_5b882_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# </style>
# <table id="T_5b882">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5b882_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_5b882_row0_col1" class="data row0 col1" >c8af453e-4f25-416c-b5de-c1ef69309336</td>
#     </tr>
#     <tr>
#       <td id="T_5b882_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_5b882_row1_col1" class="data row1 col1" >CNERT 2</td>
#     </tr>
#     <tr>
#       <td id="T_5b882_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_5b882_row2_col1" class="data row2 col1" >2023-01-15 18:59:57 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_5b882_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_5b882_row3_col1" class="data row3 col1" >2023-01-14 18:59:59 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_5b882_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_5b882_row4_col1" class="data row4 col1" >f8a6e0b0-ad14-47cb-9764-74c20ef3e4fc</td>
#     </tr>
#     <tr>
#       <td id="T_5b882_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_5b882_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_3b49e caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_3b49e th {
#   text-align: left;
# }
# #T_3b49e tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_3b49e tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_3b49e .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_3b49e_row0_col0, #T_3b49e_row0_col1, #T_3b49e_row0_col2, #T_3b49e_row0_col3, #T_3b49e_row0_col4, #T_3b49e_row0_col5, #T_3b49e_row0_col6, #T_3b49e_row0_col7, #T_3b49e_row0_col8, #T_3b49e_row0_col9, #T_3b49e_row0_col10, #T_3b49e_row0_col13, #T_3b49e_row0_col14, #T_3b49e_row0_col15, #T_3b49e_row1_col0, #T_3b49e_row1_col1, #T_3b49e_row1_col2, #T_3b49e_row1_col3, #T_3b49e_row1_col4, #T_3b49e_row1_col5, #T_3b49e_row1_col6, #T_3b49e_row1_col7, #T_3b49e_row1_col8, #T_3b49e_row1_col9, #T_3b49e_row1_col10, #T_3b49e_row1_col13, #T_3b49e_row1_col14, #T_3b49e_row1_col15, #T_3b49e_row2_col0, #T_3b49e_row2_col1, #T_3b49e_row2_col2, #T_3b49e_row2_col3, #T_3b49e_row2_col4, #T_3b49e_row2_col5, #T_3b49e_row2_col6, #T_3b49e_row2_col7, #T_3b49e_row2_col8, #T_3b49e_row2_col9, #T_3b49e_row2_col10, #T_3b49e_row2_col13, #T_3b49e_row2_col14, #T_3b49e_row2_col15, #T_3b49e_row3_col0, #T_3b49e_row3_col1, #T_3b49e_row3_col2, #T_3b49e_row3_col3, #T_3b49e_row3_col4, #T_3b49e_row3_col5, #T_3b49e_row3_col6, #T_3b49e_row3_col7, #T_3b49e_row3_col8, #T_3b49e_row3_col9, #T_3b49e_row3_col10, #T_3b49e_row3_col13, #T_3b49e_row3_col14, #T_3b49e_row3_col15, #T_3b49e_row4_col0, #T_3b49e_row4_col1, #T_3b49e_row4_col2, #T_3b49e_row4_col3, #T_3b49e_row4_col4, #T_3b49e_row4_col5, #T_3b49e_row4_col6, #T_3b49e_row4_col7, #T_3b49e_row4_col8, #T_3b49e_row4_col9, #T_3b49e_row4_col10, #T_3b49e_row4_col13, #T_3b49e_row4_col14, #T_3b49e_row4_col15, #T_3b49e_row5_col0, #T_3b49e_row5_col1, #T_3b49e_row5_col2, #T_3b49e_row5_col3, #T_3b49e_row5_col4, #T_3b49e_row5_col5, #T_3b49e_row5_col6, #T_3b49e_row5_col7, #T_3b49e_row5_col8, #T_3b49e_row5_col9, #T_3b49e_row5_col10, #T_3b49e_row5_col13, #T_3b49e_row5_col14, #T_3b49e_row5_col15, #T_3b49e_row6_col0, #T_3b49e_row6_col1, #T_3b49e_row6_col2, #T_3b49e_row6_col3, #T_3b49e_row6_col4, #T_3b49e_row6_col5, #T_3b49e_row6_col6, #T_3b49e_row6_col7, #T_3b49e_row6_col8, #T_3b49e_row6_col9, #T_3b49e_row6_col10, #T_3b49e_row6_col13, #T_3b49e_row6_col14, #T_3b49e_row6_col15, #T_3b49e_row7_col0, #T_3b49e_row7_col1, #T_3b49e_row7_col2, #T_3b49e_row7_col3, #T_3b49e_row7_col4, #T_3b49e_row7_col5, #T_3b49e_row7_col6, #T_3b49e_row7_col7, #T_3b49e_row7_col8, #T_3b49e_row7_col9, #T_3b49e_row7_col10, #T_3b49e_row7_col13, #T_3b49e_row7_col14, #T_3b49e_row7_col15 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_3b49e_row0_col11, #T_3b49e_row1_col11, #T_3b49e_row2_col11, #T_3b49e_row3_col11, #T_3b49e_row4_col11, #T_3b49e_row5_col11, #T_3b49e_row6_col11, #T_3b49e_row7_col11 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_3b49e_row0_col12, #T_3b49e_row1_col12, #T_3b49e_row2_col12, #T_3b49e_row3_col12, #T_3b49e_row4_col12, #T_3b49e_row5_col12, #T_3b49e_row6_col12, #T_3b49e_row7_col12 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_3b49e">
#   <caption>Nodes</caption>
#   <thead>
#     <tr>
#       <th id="T_3b49e_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_3b49e_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_3b49e_level0_col2" class="col_heading level0 col2" >Cores</th>
#       <th id="T_3b49e_level0_col3" class="col_heading level0 col3" >RAM</th>
#       <th id="T_3b49e_level0_col4" class="col_heading level0 col4" >Disk</th>
#       <th id="T_3b49e_level0_col5" class="col_heading level0 col5" >Image</th>
#       <th id="T_3b49e_level0_col6" class="col_heading level0 col6" >Image Type</th>
#       <th id="T_3b49e_level0_col7" class="col_heading level0 col7" >Host</th>
#       <th id="T_3b49e_level0_col8" class="col_heading level0 col8" >Site</th>
#       <th id="T_3b49e_level0_col9" class="col_heading level0 col9" >Username</th>
#       <th id="T_3b49e_level0_col10" class="col_heading level0 col10" >Management IP</th>
#       <th id="T_3b49e_level0_col11" class="col_heading level0 col11" >State</th>
#       <th id="T_3b49e_level0_col12" class="col_heading level0 col12" >Error</th>
#       <th id="T_3b49e_level0_col13" class="col_heading level0 col13" >SSH Command</th>
#       <th id="T_3b49e_level0_col14" class="col_heading level0 col14" >Public SSH Key File</th>
#       <th id="T_3b49e_level0_col15" class="col_heading level0 col15" >Private SSH Key File</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3b49e_row0_col0" class="data row0 col0" >c894d690-fd7d-4c00-993e-a1effc655796</td>
#       <td id="T_3b49e_row0_col1" class="data row0 col1" >s1</td>
#       <td id="T_3b49e_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_3b49e_row0_col3" class="data row0 col3" >8</td>
#       <td id="T_3b49e_row0_col4" class="data row0 col4" >100</td>
#       <td id="T_3b49e_row0_col5" class="data row0 col5" >default_ubuntu_20</td>
#       <td id="T_3b49e_row0_col6" class="data row0 col6" >qcow2</td>
#       <td id="T_3b49e_row0_col7" class="data row0 col7" >tacc-w2.fabric-testbed.net</td>
#       <td id="T_3b49e_row0_col8" class="data row0 col8" >TACC</td>
#       <td id="T_3b49e_row0_col9" class="data row0 col9" >ubuntu</td>
#       <td id="T_3b49e_row0_col10" class="data row0 col10" >129.114.110.79</td>
#       <td id="T_3b49e_row0_col11" class="data row0 col11" >Active</td>
#       <td id="T_3b49e_row0_col12" class="data row0 col12" ></td>
#       <td id="T_3b49e_row0_col13" class="data row0 col13" >ssh -i /home/fabric/work/fabric_config/.ssh/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@129.114.110.79</td>
#       <td id="T_3b49e_row0_col14" class="data row0 col14" >/home/fabric/work/fabric_config/.ssh/slice_key.pub</td>
#       <td id="T_3b49e_row0_col15" class="data row0 col15" >/home/fabric/work/fabric_config/.ssh/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_3b49e_row1_col0" class="data row1 col0" >e5b1a58f-0077-43df-88f7-81458f246436</td>
#       <td id="T_3b49e_row1_col1" class="data row1 col1" >s2</td>
#       <td id="T_3b49e_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_3b49e_row1_col3" class="data row1 col3" >8</td>
#       <td id="T_3b49e_row1_col4" class="data row1 col4" >100</td>
#       <td id="T_3b49e_row1_col5" class="data row1 col5" >default_ubuntu_20</td>
#       <td id="T_3b49e_row1_col6" class="data row1 col6" >qcow2</td>
#       <td id="T_3b49e_row1_col7" class="data row1 col7" >tacc-w2.fabric-testbed.net</td>
#       <td id="T_3b49e_row1_col8" class="data row1 col8" >TACC</td>
#       <td id="T_3b49e_row1_col9" class="data row1 col9" >ubuntu</td>
#       <td id="T_3b49e_row1_col10" class="data row1 col10" >129.114.110.120</td>
#       <td id="T_3b49e_row1_col11" class="data row1 col11" >Active</td>
#       <td id="T_3b49e_row1_col12" class="data row1 col12" ></td>
#       <td id="T_3b49e_row1_col13" class="data row1 col13" >ssh -i /home/fabric/work/fabric_config/.ssh/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@129.114.110.120</td>
#       <td id="T_3b49e_row1_col14" class="data row1 col14" >/home/fabric/work/fabric_config/.ssh/slice_key.pub</td>
#       <td id="T_3b49e_row1_col15" class="data row1 col15" >/home/fabric/work/fabric_config/.ssh/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_3b49e_row2_col0" class="data row2 col0" >13c4a558-37f1-4925-b88f-862ef357283f</td>
#       <td id="T_3b49e_row2_col1" class="data row2 col1" >s3</td>
#       <td id="T_3b49e_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_3b49e_row2_col3" class="data row2 col3" >8</td>
#       <td id="T_3b49e_row2_col4" class="data row2 col4" >100</td>
#       <td id="T_3b49e_row2_col5" class="data row2 col5" >default_ubuntu_20</td>
#       <td id="T_3b49e_row2_col6" class="data row2 col6" >qcow2</td>
#       <t
# <style type="text/css">
# #T_99c6d caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_99c6d th {
#   text-align: left;
# }
# #T_99c6d tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_99c6d tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_99c6d .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_99c6d_row0_col0, #T_99c6d_row0_col1, #T_99c6d_row0_col2, #T_99c6d_row0_col3, #T_99c6d_row0_col4, #T_99c6d_row0_col5, #T_99c6d_row0_col6, #T_99c6d_row1_col0, #T_99c6d_row1_col1, #T_99c6d_row1_col2, #T_99c6d_row1_col3, #T_99c6d_row1_col4, #T_99c6d_row1_col5, #T_99c6d_row1_col6, #T_99c6d_row2_col0, #T_99c6d_row2_col1, #T_99c6d_row2_col2, #T_99c6d_row2_col3, #T_99c6d_row2_col4, #T_99c6d_row2_col5, #T_99c6d_row2_col6, #T_99c6d_row3_col0, #T_99c6d_row3_col1, #T_99c6d_row3_col2, #T_99c6d_row3_col3, #T_99c6d_row3_col4, #T_99c6d_row3_col5, #T_99c6d_row3_col6, #T_99c6d_row4_col0, #T_99c6d_row4_col1, #T_99c6d_row4_col2, #T_99c6d_row4_col3, #T_99c6d_row4_col4, #T_99c6d_row4_col5, #T_99c6d_row4_col6, #T_99c6d_row5_col0, #T_99c6d_row5_col1, #T_99c6d_row5_col2, #T_99c6d_row5_col3, #T_99c6d_row5_col4, #T_99c6d_row5_col5, #T_99c6d_row5_col6, #T_99c6d_row6_col0, #T_99c6d_row6_col1, #T_99c6d_row6_col2, #T_99c6d_row6_col3, #T_99c6d_row6_col4, #T_99c6d_row6_col5, #T_99c6d_row6_col6, #T_99c6d_row7_col0, #T_99c6d_row7_col1, #T_99c6d_row7_col2, #T_99c6d_row7_col3, #T_99c6d_row7_col4, #T_99c6d_row7_col5, #T_99c6d_row7_col6 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_99c6d_row0_col7, #T_99c6d_row1_col7, #T_99c6d_row2_col7, #T_99c6d_row3_col7, #T_99c6d_row4_col7, #T_99c6d_row5_col7, #T_99c6d_row6_col7, #T_99c6d_row7_col7 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_99c6d_row0_col8, #T_99c6d_row1_col8, #T_99c6d_row2_col8, #T_99c6d_row3_col8, #T_99c6d_row4_col8, #T_99c6d_row5_col8, #T_99c6d_row6_col8, #T_99c6d_row7_col8 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_99c6d">
#   <caption>Networks</caption>
#   <thead>
#     <tr>
#       <th id="T_99c6d_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_99c6d_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_99c6d_level0_col2" class="col_heading level0 col2" >Layer</th>
#       <th id="T_99c6d_level0_col3" class="col_heading level0 col3" >Type</th>
#       <th id="T_99c6d_level0_col4" class="col_heading level0 col4" >Site</th>
#       <th id="T_99c6d_level0_col5" class="col_heading level0 col5" >Gateway</th>
#       <th id="T_99c6d_level0_col6" class="col_heading level0 col6" >Subnet</th>
#       <th id="T_99c6d_level0_col7" class="col_heading level0 col7" >State</th>
#       <th id="T_99c6d_level0_col8" class="col_heading level0 col8" >Error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_99c6d_row0_col0" class="data row0 col0" >f7498958-8e99-4cc1-a3af-a6a232ca2296</td>
#       <td id="T_99c6d_row0_col1" class="data row0 col1" >net_s1_s2</td>
#       <td id="T_99c6d_row0_col2" class="data row0 col2" >L2</td>
#       <td id="T_99c6d_row0_col3" class="data row0 col3" >L2Bridge</td>
#       <td id="T_99c6d_row0_col4" class="data row0 col4" >TACC</td>
#       <td id="T_99c6d_row0_col5" class="data row0 col5" >None</td>
#       <td id="T_99c6d_row0_col6" class="data row0 col6" >None</td>
#       <td id="T_99c6d_row0_col7" class="data row0 col7" >Active</td>
#       <td id="T_99c6d_row0_col8" class="data row0 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_99c6d_row1_col0" class="data row1 col0" >c6029d90-ac63-4a77-8a06-5d174fc7aef4</td>
#       <td id="T_99c6d_row1_col1" class="data row1 col1" >net_s2_s3</td>
#       <td id="T_99c6d_row1_col2" class="data row1 col2" >L2</td>
#       <td id="T_99c6d_row1_col3" class="data row1 col3" >L2Bridge</td>
#       <td id="T_99c6d_row1_col4" class="data row1 col4" >TACC</td>
#       <td id="T_99c6d_row1_col5" class="data row1 col5" >None</td>
#       <td id="T_99c6d_row1_col6" class="data row1 col6" >None</td>
#       <td id="T_99c6d_row1_col7" class="data row1 col7" >Active</td>
#       <td id="T_99c6d_row1_col8" class="data row1 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_99c6d_row2_col0" class="data row2 col0" >3fbaaded-2c6c-4c60-8c04-7248017f772c</td>
#       <td id="T_99c6d_row2_col1" class="data row2 col1" >net_s1_s3</td>
#       <td id="T_99c6d_row2_col2" class="data row2 col2" >L2</td>
#       <td id="T_99c6d_row2_col3" class="data row2 col3" >L2Bridge</td>
#       <td id="T_99c6d_row2_col4" class="data row2 col4" >TACC</td>
#       <td id="T_99c6d_row2_col5" class="data row2 col5" >None</td>
#       <td id="T_99c6d_row2_col6" class="data row2 col6" >None</td>
#       <td id="T_99c6d_row2_col7" class="data row2 col7" >Active</td>
#       <td id="T_99c6d_row2_col8" class="data row2 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_99c6d_row3_col0" class="data row3 col0" >28b91522-23ab-422c-89e7-753a7b75583a</td>
#       <td id="T_99c6d_row3_col1" class="data row3 col1" >net_h1</td>
#       <td id="T_99c6d_row3_col2" class="data row3 col2" >L2</td>
#       <td id="T_99c6d_row3_col3" class="data row3 col3" >L2Bridge</td>
#       <td id="T_99c6d_row3_col4" class="data row3 col4" >TACC</td>
#       <td id="T_99c6d_row3_col5" class="data row3 col5" >None</td>
#       <td id="T_99c6d_row3_col6" class="data row3 col6" >None</td>
#       <td id="T_99c6d_row3_col7" class="data row3 col7" >Active</td>
#       <td id="T_99c6d_row3_col8" class="data row3 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_99c6d_row4_col0" class="data row4 col0" >1eced5b6-25b2-4550-bad2-9e39835df764</td>
#       <td id="T_99c6d_row4_col1" class="data row4 col1" >net_h11</td>
#       <td id="T_99c6d_row4_col2" class="data row4 col2" >L2</td>
#       <td id="T_99c6d_row4_col3" class="data row4 col3" >L2Bridge</td>
#       <td id="T_99c6d_row4_col4" class="data row4 col4" >TACC</td>
#       <td id="T_99c6d_row4_col5" class="data row4 col5" >None</td>
#       <td id="T_99c6d_row4_col6" class="data row4 col6" >None</td>
#       <td id="T_99c6d_row4_col7" class="data row4 col7" >Active</td>
#       <td id="T_99c6d_row4_col8" class="data row4 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_99c6d_row5_col0" class="data row5 col0" >b73d94aa-b984-4926-ac59-121a672f4f2f</td>
#       <td id="T_99c6d_row5_col1" class="data row5 col1" >net_h2</td>
#       <td id="T_99c6d_row5_col2" class="data row5 col2" >L2</td>
#       <td id="T_99c6d_row5_col3" class="data row5 col3" >L2Bridge</td>
#       <td id="T_99c6d_row5_col4" class="data row5 col4" >TACC</td>
#       <td id="T_99c6d_row5_col5" class="data row5 col5" >None</td>
#       <td id="T_99c6d_row5_col6" class="data row5 col6" >None</td>
#       <td id="T_99c6d_row5_col7" class="data row5 col7" >Active</td>
#       <td id="T_99c6d_row5_col8" class="data row5 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_99c6d_row6_col0" class="data row6 col0" >ecac1d88-6379-47f6-a170-56177e7d43e9</td>
#       <td id="T_99c6d_row6_col1" class="data row6 col1" >net_h22</td>
#       <td id="T_99c6d_row6_col2" class="data row6 col2" >L2</td>
#       <td id="T_99c6d_row6_col3" class="data row6 col3" >L2Bridge</td>
#       <td id="T_99c6d_row6_col4" class="data row6 col4" >TACC</td>
#       <td id="T_99c6d_row6_col5" class="data row6 col5" >None</td>
#       <td id="T_99c6d_row6_col6" class="data row6 col6" >None</td>
#       <td id="T_99c6d_row6_col7" class="data row6 col7" >Active</td>
#       <td id="T_99c6d_row6_col8" class="data row6 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_99c6d_row7_col0" class="data row7 col0" >e97d7dd6-92fc-4180-975d-99576353fa14</td>
#       <td id="T_99c6d_row7_col1" class="data row7 col1" >net_h3</td>
#       <td id="T_99c6d_row7_col2" class="data row7 col2" >L2</td>
#       <td id="T_99c6d_row7_col3" class="data row7 col3" >L2Bridge</td>
#       <td id="T_99c6d_row7_col4" class="data row7 col4" >TACC</td>
#       <td id="T_99c6d_row7_col5" class="data row7 col5" >None</td>
# Time to stable 341 seconds
# Running post_boot_config ...  sudo: nmcli: command not found
#   sudo: nmcli: command not found
#   sudo: nmcli: command not found
#   sudo: nmcli: command not found
#   sudo: nmcli: command not found
#   sudo: nmcli: command not found
#   sudo: nmcli: command not found
#   sudo: nmcli: command not found
#   sudo: nmcli: command not found
#   sudo: nmcli: command not found
#   sudo: nmcli: command not found
#   sudo: nmcli: command not found
#   sudo: nmcli: command not found
#   sudo: nmcli: command not found
#   sudo: nmcli: command not found
#   sudo: nmcli: command not found
#  Time to post boot config 397 seconds
# <style type="text/css">
# #T_feb1d caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_feb1d th {
#   text-align: left;
# }
# #T_feb1d tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_feb1d tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_feb1d .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_feb1d_row0_col0, #T_feb1d_row0_col1, #T_feb1d_row0_col2, #T_feb1d_row0_col3, #T_feb1d_row0_col4, #T_feb1d_row0_col5, #T_feb1d_row0_col6, #T_feb1d_row0_col7, #T_feb1d_row1_col0, #T_feb1d_row1_col1, #T_feb1d_row1_col2, #T_feb1d_row1_col3, #T_feb1d_row1_col4, #T_feb1d_row1_col5, #T_feb1d_row1_col6, #T_feb1d_row1_col7, #T_feb1d_row2_col0, #T_feb1d_row2_col1, #T_feb1d_row2_col2, #T_feb1d_row2_col3, #T_feb1d_row2_col4, #T_feb1d_row2_col5, #T_feb1d_row2_col6, #T_feb1d_row2_col7, #T_feb1d_row3_col0, #T_feb1d_row3_col1, #T_feb1d_row3_col2, #T_feb1d_row3_col3, #T_feb1d_row3_col4, #T_feb1d_row3_col5, #T_feb1d_row3_col6, #T_feb1d_row3_col7, #T_feb1d_row4_col0, #T_feb1d_row4_col1, #T_feb1d_row4_col2, #T_feb1d_row4_col3, #T_feb1d_row4_col4, #T_feb1d_row4_col5, #T_feb1d_row4_col6, #T_feb1d_row4_col7, #T_feb1d_row5_col0, #T_feb1d_row5_col1, #T_feb1d_row5_col2, #T_feb1d_row5_col3, #T_feb1d_row5_col4, #T_feb1d_row5_col5, #T_feb1d_row5_col6, #T_feb1d_row5_col7, #T_feb1d_row6_col0, #T_feb1d_row6_col1, #T_feb1d_row6_col2, #T_feb1d_row6_col3, #T_feb1d_row6_col4, #T_feb1d_row6_col5, #T_feb1d_row6_col6, #T_feb1d_row6_col7, #T_feb1d_row7_col0, #T_feb1d_row7_col1, #T_feb1d_row7_col2, #T_feb1d_row7_col3, #T_feb1d_row7_col4, #T_feb1d_row7_col5, #T_feb1d_row7_col6, #T_feb1d_row7_col7, #T_feb1d_row8_col0, #T_feb1d_row8_col1, #T_feb1d_row8_col2, #T_feb1d_row8_col3, #T_feb1d_row8_col4, #T_feb1d_row8_col5, #T_feb1d_row8_col6, #T_feb1d_row8_col7, #T_feb1d_row9_col0, #T_feb1d_row9_col1, #T_feb1d_row9_col2, #T_feb1d_row9_col3, #T_feb1d_row9_col4, #T_feb1d_row9_col5, #T_feb1d_row9_col6, #T_feb1d_row9_col7, #T_feb1d_row10_col0, #T_feb1d_row10_col1, #T_feb1d_row10_col2, #T_feb1d_row10_col3, #T_feb1d_row10_col4, #T_feb1d_row10_col5, #T_feb1d_row10_col6, #T_feb1d_row10_col7, #T_feb1d_row11_col0, #T_feb1d_row11_col1, #T_feb1d_row11_col2, #T_feb1d_row11_col3, #T_feb1d_row11_col4, #T_feb1d_row11_col5, #T_feb1d_row11_col6, #T_feb1d_row11_col7, #T_feb1d_row12_col0, #T_feb1d_row12_col1, #T_feb1d_row12_col2, #T_feb1d_row12_col3, #T_feb1d_row12_col4, #T_feb1d_row12_col5, #T_feb1d_row12_col6, #T_feb1d_row12_col7, #T_feb1d_row13_col0, #T_feb1d_row13_col1, #T_feb1d_row13_col2, #T_feb1d_row13_col3, #T_feb1d_row13_col4, #T_feb1d_row13_col5, #T_feb1d_row13_col6, #T_feb1d_row13_col7, #T_feb1d_row14_col0, #T_feb1d_row14_col1, #T_feb1d_row14_col2, #T_feb1d_row14_col3, #T_feb1d_row14_col4, #T_feb1d_row14_col5, #T_feb1d_row14_col6, #T_feb1d_row14_col7, #T_feb1d_row15_col0, #T_feb1d_row15_col1, #T_feb1d_row15_col2, #T_feb1d_row15_col3, #T_feb1d_row15_col4, #T_feb1d_row15_col5, #T_feb1d_row15_col6, #T_feb1d_row15_col7 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_feb1d">
#   <caption>Interfaces</caption>
#   <thead>
#     <tr>
#       <th id="T_feb1d_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_feb1d_level0_col1" class="col_heading level0 col1" >Node</th>
#       <th id="T_feb1d_level0_col2" class="col_heading level0 col2" >Network</th>
#       <th id="T_feb1d_level0_col3" class="col_heading level0 col3" >Bandwidth</th>
#       <th id="T_feb1d_level0_col4" class="col_heading level0 col4" >VLAN</th>
#       <th id="T_feb1d_level0_col5" class="col_heading level0 col5" >MAC</th>
#       <th id="T_feb1d_level0_col6" class="col_heading level0 col6" >Physical Device</th>
#       <th id="T_feb1d_level0_col7" class="col_heading level0 col7" >Device</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_feb1d_row0_col0" class="data row0 col0" >s1-s1_iface_h1-p1</td>
#       <td id="T_feb1d_row0_col1" class="data row0 col1" >s1</td>
#       <td id="T_feb1d_row0_col2" class="data row0 col2" >net_h1</td>
#       <td id="T_feb1d_row0_col3" class="data row0 col3" >100</td>
#       <td id="T_feb1d_row0_col4" class="data row0 col4" >None</td>
#       <td id="T_feb1d_row0_col5" class="data row0 col5" >2A:B7:3C:BF:5B:66</td>
#       <td id="T_feb1d_row0_col6" class="data row0 col6" >ens10</td>
#       <td id="T_feb1d_row0_col7" class="data row0 col7" >ens10</td>
#     </tr>
#     <tr>
#       <td id="T_feb1d_row1_col0" class="data row1 col0" >s1-s1_iface_to_s3-p1</td>
#       <td id="T_feb1d_row1_col1" class="data row1 col1" >s1</td>
#       <td id="T_feb1d_row1_col2" class="data row1 col2" >net_s1_s3</td>
#       <td id="T_feb1d_row1_col3" class="data row1 col3" >100</td>
#       <td id="T_feb1d_row1_col4" class="data row1 col4" >None</td>
#       <td id="T_feb1d_row1_col5" class="data row1 col5" >26:E1:33:6D:4F:8B</td>
#       <td id="T_feb1d_row1_col6" class="data row1 col6" >ens8</td>
#       <td id="T_feb1d_row1_col7" class="data row1 col7" >ens8</td>
#     </tr>
#     <tr>
#       <td id="T_feb1d_row2_col0" class="data row2 col0" >s1-s1_iface_h11-p1</td>
#       <td id="T_feb1d_row2_col1" class="data row2 col1" >s1</td>
#       <td id="T_feb1d_row2_col2" class="data row2 col2" >net_h11</td>
#       <td id="T_feb1d_row2_col3" class="data row2 col3" >100</td>
#       <td id="T_feb1d_row2_col4" class="data row2 col4" >None</td>
#       <td id="T_feb1d_row2_col5" class="data row2 col5" >26:C6:B9:7D:D5:22</td>
#       <td id="T_feb1d_row2_col6" class="data row2 col6" >ens7</td>
#       <td id="T_feb1d_row2_col7" class="data row2 col7" >ens7</td>
#     </tr>
#     <tr>
#       <td id="T_feb1d_row3_col0" class="data row3 col0" >s1-s1_iface_to_s2-p1</td>
#       <td id="T_feb1d_row3_col1" class="data row3 col1" >s1</td>
#       <td id="T_feb1d_row3_col2" class="data row3 col2" >net_s1_s2</td>
#       <td id="T_feb1d_row3_col3" class="data row3 col3" >100</td>
#       <td id="T_feb1d_row3_col4" class="data row3 col4" >None</td>
#       <td id="T_feb1d_row3_col5" class="data row3 col5" >2A:95:DD:38:25:EF</td>
#       <td id="T_feb1d_row3_col6" class="data row3 col6" >ens9</td>
#       <td id="T_feb1d_row3_col7" class="data row3 col7" >ens9</td>
#     </tr>
#     <tr>
#       <td id="T_feb1d_row4_col0" class="data row4 col0" >s2-s2_iface_h22-p1</td>
#       <td id="T_feb1d_row4_col1" class="data row4 col1" >s2</td>
#       <td id="T_feb1d_row4_col2" class="data row4 col2" >net_h22</td>
#       <td id="T_feb1d_row4_col3" class="data row4 col3" >100</td>
#       <td id="T_feb1d_row4_col4" class="data row4 col4" >None</td>
#       <td id="T_feb1d_row4_col5" class="data row4 col5" >2E:7A:CC:99:81:29</td>
#       <td id="T_feb1d_row4_col6" class="data row4 col6" >ens7</td>
#       <td id="T_feb1d_row4_col7" class="data row4 col7" >ens7</td>
#     </tr>
#     <tr>
#       <td id="T_feb1d_row5_col0" class="data row5 col0" >s2-s2_iface_to_s1-p1</td>
#       <td id="T_feb1d_row5_col1" class="data row5 col1" >s2</td>
#       <td id="T_feb1d_row5_col2" class="data row5 col2" >net_s1_s2</td>
#       <td id="T_feb1d_row5_col3" class="data row5 col3" >100</td>
#       <td id="T_feb1d_row5_col4" class="data row5 col4" >None</td>
#       <td id="T_feb1d_row5_col5" class="data row5 col5" >32:35:D1:70:7E:1D</td>
#       <td id="T_feb1d_row5_col6" class="data row5 col6" >ens8</td>
#       <td id="T_feb1d_row5_col7" class="data row5 col7" >ens8</td>
#     </tr>
#     <tr>
#       <td id="T_feb1d_row6_col0" class="data row6 col0" >s2-s2_iface_h2-p1</td>
#       <td id="T_feb1d_row6_col1" class="data row6 col1" >s2</td>
#       <td id="T_feb1d_row6_col2" class="data row6 col2" >net_h2</td>
#       <td id="T_feb1d_row6_col3" class="data row6 col3" >100</td>
#       <td id="T_feb1d_row6_col4" class="data row6 col4" >None</td>
#       <td id="T_feb1d_row6_col5" class="data row6 col5" >3A:AC:16:A5:F5:44</td>
#       <td id="T_feb1d_row6_col6" class="data row6 col6" >ens10</td>
#       <td id="T_feb1d_row6_col7" class="data row6 col7" >ens10</td>
#     </tr>
#     <tr>
#       <td id="T_feb1d_row7_col0" class="data row7 col0" >s2-s2_iface_t
# Time to print interfaces 429 seconds

# %%
def checkInetConnection(node):
    try:

        #If the node is an IPv6 Node then configure NAT64
        if type(ip_address(node.get_management_ip())) is IPv6Address:
            print("This code only works with ip4, reconfigure nodes")
            return

        #Access non-IPv6 Services
        stdout, stderr = node.execute(f'sudo apt-get update -qq && sudo apt install -y net-tools && git clone https://github.com/fabric-testbed/jupyter-examples.git && sudo apt install -y ffmpeg')
        # print(stdout)
        # print(stderr)

        stdout, stderr = node.execute(f'ls jupyter-examples')
        print(stdout)
        print(stderr)
        
        stdout, stderr = node.execute(f'ifconfig | grep ens')
        print(stdout)
        print(stderr)


    except Exception as e:
        print(f"Exception: {e}")

# %%
try:
    slice = fablib.get_slice(name=slice_name)
    for node in slice.get_nodes():
        print("Node:")
        print(f"   Name              : {node.get_name()}")
        checkInetConnection(node)
except Exception as e:
    print(f"Fail: {e}")
    traceback.print_exc()
# Out:
# Node:
#    Name              : s1
# Reading package lists...
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# Building dependency tree...
# Reading state information...
# The following NEW packages will be installed:
#   net-tools
# 0 upgraded, 1 newly installed, 0 to remove and 183 not upgraded.
# Need to get 196 kB of archives.
# After this operation, 864 kB of additional disk space will be used.
# Get:1 http://nova.clouds.archive.ubuntu.com/ubuntu focal/main amd64 net-tools amd64 1.60+git20180626.aebd88e-1ubuntu1 [196 kB]
#  debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
#   debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
#   dpkg-preconfigure: unable to re-open stdin:
#  Fetched 196 kB in 1s (253 kB/s)
# Selecting previously unselected package net-tools.
# (Reading database ... 63577 files and directories currently installed.)
# Preparing to unpack .../net-tools_1.60+git20180626.aebd88e-1ubuntu1_amd64.deb ...
# Unpacking net-tools (1.60+git20180626.aebd88e-1ubuntu1) ...
# Setting up net-tools (1.60+git20180626.aebd88e-1ubuntu1) ...
# Processing triggers for man-db (2.9.1-1) ...
#  Cloning into 'jupyter-examples'...
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#  Reading package lists...
# Building dependency tree...
# Reading state information...
# The following additional packages will be installed:
#   fontconfig fontconfig-config fonts-dejavu-core i965-va-driver
#   intel-media-va-driver libaacs0 libaom0 libass9 libasyncns0 libavc1394-0
#   libavcodec58 libavdevice58 libavfilter7 libavformat58 libavresample4
#   libavutil56 libbdplus0 libbluray2 libbs2b0 libcaca0 libcairo-gobject2
#   libcairo2 libcdio-cdda2 libcdio-paranoia2 libcdio18 libchromaprint1
#   libcodec2-0.9 libdatrie1 libdc1394-22 libdrm-amdgpu1 libdrm-intel1
#   libdrm-nouveau2 libdrm-radeon1 libfftw3-double3 libflac8 libflite1
#   libfontconfig1 libgdk-pixbuf2.0-0 libgdk-pixbuf2.0-bin
#   libgdk-pixbuf2.0-common libgl1 libgl1-mesa-dri libglapi-mesa libglvnd0
#   libglx-mesa0 libglx0 libgme0 libgomp1 libgraphite2-3 libgsm1 libharfbuzz0b
#   libiec61883-0 libigdgmm11 libjack-jackd2-0 libjbig0 libjpeg-turbo8 libjpeg8
#   liblilv-0-0 libllvm12 libmp3lame0 libmpg123-0 libmysofa1 libnorm1
#   libopenal-data libopenal1 libopenjp2-7 libopenmpt0 libopus0 libpango-1.0-0
#   libpangocairo-1.0-0 libpangoft2-1.0-0 libpciaccess0 libpgm-5.2-0
#   libpixman-1-0 libpostproc55 libpulse0 libraw1394-11 librsvg2-2
#   librsvg2-common librubberband2 libsamplerate0 libsdl2-2.0-0
#   libsensors-config libsensors5 libserd-0-0 libshine3 libsnappy1v5 libsndfile1
#   libsndio7.0 libsord-0-0 libsoxr0 libspeex1 libsratom-0-0 libssh-gcrypt-4
#   libswresample3 libswscale5 libthai-data libthai0 libtheora0 libtiff5
#   libtwolame0 libva-drm2 libva-x11-2 libva2 libvdpau1 libvidstab1.1
#   libvorbisenc2 libvpx6 libvulkan1 libwavpack1 libwayland-client0
#   libwayland-cursor0 libwayland-egl1 libwebp6 libwebpmux3 libx11-xcb1
#   libx264-155 libx265-179 libxcb-dri2-0 libxcb-dri3-0 libxcb-glx0
#   libxcb-present0 libxcb-randr0 libxcb-render0 libxcb-shape0 libxcb-shm0
#   libxcb-sync1 libxcb-xfixes0 libxcursor1 libxfixes3 libxi6 libxinerama1
#   libxkbcommon0 libxrandr2 libxrender1 libxshmfence1 libxss1 libxv1
#   libxvidcore4 libxxf86vm1 libzmq5 libzvbi-common libzvbi0 mesa-va-drivers
#   mesa-vdpau-drivers mesa-vulkan-drivers ocl-icd-libopencl1 va-driver-all
#   vdpau-driver-all x11-common
# Suggested packages:
#   ffmpeg-doc i965-va-driver-shaders libbluray-bdj libfftw3-bin libfftw3-dev
#   jackd2 libportaudio2 opus-tools pulseaudio libraw1394-doc librsvg2-bin
#   lm-sensors serdi sndiod sordi speex opencl-icd libvdpau-va-gl1
#   nvidia-vdpau-driver nvidia-legacy-340xx-vdpau-driver
#   nvidia-legacy-304xx-vdpau-driver
# The following NEW packages will be installed:
#   ffmpeg fontconfig fontconfig-config fonts-dejavu-core i965-va-driver
#   intel-media-va-driver libaacs0 libaom0 libass9 libasyncns0 libavc1394-0
#   libavcodec58 libavdevice58 libavfilter7 libavformat58 libavresample4
#   libavutil56 libbdplus0 libbluray2 libbs2b0 libcaca0 libcairo-gobject2
#   libcairo2 libcdio-cdda2 libcdio-paranoia2 libcdio18 libchromaprint1
#   libcodec2-0.9 libdatrie1 libdc1394-22 libdrm-amdgpu1 libdrm-intel1
#   libdrm-nouveau2 libdrm-radeon1 libfftw3-double3 libflac8 libflite1
#   libfontconfig1 libgdk-pixbuf2.0-0 libgdk-pixbuf2.0-bin
#   libgdk-pixbuf2.0-common libgl1 libgl1-mesa-dri libglapi-mesa libglvnd0
#   libglx-mesa0 libglx0 libgme0 libgomp1 libgraphite2-3 libgsm1 libharfbuzz0b
#   libiec61883-0 libigdgmm11 libjack-jackd2-0 libjbig0 libjpeg-turbo8 libjpeg8
#   liblilv-0-0 libllvm12 libmp3lame0 libmpg123-0 libmysofa1 libnorm1
#   libopenal-data libopenal1 libopenjp2-7 libopenmpt0 libopus0 libpango-1.0-0
#   libpangocairo-1.0-0 libpangoft2-1.0-0 libpciaccess0 libpgm-5.2-0
#   libpixman-1-0 libpostproc55 libpulse0 libraw1394-11 librsvg2-2
#   librsvg2-common librubberband2 libsamplerate0 libsdl2-2.0-0
#   libsensors-config libsensors5 libserd-0-0 libshine3 libsnappy1v5 libsndfile1
#   libsndio7.0 libsord-0-0 libsoxr0 libspeex1 libsratom-0-0 libssh-gcrypt-4
#   libswresample3 libswscale5 libthai-data libthai0 libtheora0 libtiff5
#   libtwolame0 libva-drm2 libva-x11-2 libva2 libvdpau1 libvidstab1.1
#   libvorbisenc2 libvpx6 libvulkan1 libwavpack1 libwayland-client0
#   libwayland-cursor0 libwayland-egl1 libwebp6 libwebpmux3 libx11-xcb1
#   libx264-155 libx265-179 libxcb-dri2-0 libxcb-dri3-0 libxcb-glx0
#   libxcb-present0 libxcb-randr0 libxcb-render0 libxcb-shape0 libxcb-shm0
#   libxcb-sync1 libxcb-xfixes0 libxcursor1 libxfixes3 libxi6 libxinerama1
#   libxkbcommon0 libxrandr2 libxrender1 libxshmfence1 libxss1 libxv1
#   libxvidcore4 libxxf86vm1 libzmq5 libzvbi-common libzvbi0 mesa-va-drivers
#   mesa-vdpau-drivers mesa-vulkan-drivers ocl-icd-libopencl1 va-driver-all
#   vdpau-driver-all x11-common
# 0 upgraded, 151 newly installed, 0 to remove and 183 not upgraded.
# Need to get 92.9 MB of archives.
# After this operation, 768 MB of additional disk space will be used.
# Do you want to continue? [Y/n] Abort.
# Changelog.md
# LICENSE
# Readme.md
# configure.ipynb
# fabric_examples
# requirements.txt
# start_here.ipynb
# Changelog.md
# LICENSE
# Readme.md
# configure.ipynb
# fabric_examples
# requirements.txt
# start_here.ipynb
#
#
# ens3: flags=4163<UP,BROADCAST,RUNNING,MULTICAST>  mtu 9000
# ens3: flags=4163<UP,BROADCAST,RUNNING,MULTICAST>  mtu 9000
#
#
# Node:
#    Name              : s2
# Reading package lists...
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# Building dependency tree...
# Reading state information...
# The following NEW packages will be installed:
#   net-tools
# 0 upgraded, 1 newly installed, 0 to remove and 183 not upgraded.
# Need to get 196 kB of archives.
# After this operation, 864 kB of additional disk space will be used.
# Get:1 http://nova.clouds.archive.ubuntu.com/ubuntu focal/main amd64 net-tools amd64 1.60+git20180626.aebd88e-1ubuntu1 [196 kB]
#  debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
#  Fetched 196 kB in 0s (545 kB/s)
#  debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
#  Selecting previously unselected package net-tools.
# (Reading database ... 63577 files and directories currently installed.)
# Preparing to unpack .../net-tools_1.60+git20180626.aebd88e-1ubuntu1_amd64.deb ...
# Unpacking net-tools (1.60+git20180626.aebd88e-1ubuntu1) ...
# Setting up net-tools (1.60+git20180626.aebd88e-1ubuntu1) ...
# Processing triggers for man-db (2.9.1-1) ...
#  Cloning into 'jupyter-examples'...
#
# WARNING: apt   does not have a stable CLI interface. Use with caution in scripts.
#
#  Reading package lists...
# Building dependency tree...
# Reading state information...
# The following additional packages will be installed:
#   fontconfig fontconfig-config fonts-dejavu-core i965-va-driver
#   intel-media-va-driver libaacs0 libaom0 libass9 libasyncns0 libavc1394-0
#   libavcodec58 libavdevice58 libavfilter7 libavformat58 libavresample4
#   libavutil56 libbdplus0 libbluray2 libbs2b0 libcaca0 libcairo-gobject2
#   libcairo2 libcdio-cdda2 libcdio-paranoia2 libcdio18 libchromaprint1
#   libcodec2-0.9 libdatrie1 libdc1394-22 libdrm-amdgpu1 libdrm-intel1
#   libdrm-nouveau2 libdrm-radeon1 libfftw3-double3 libflac8 libflite1
#   libfontconfig1 libgdk-pixbuf2.0-0 libgdk-pixbuf2.0-bin
#   libgdk-pixbuf2.0-common libgl1 libgl1-mesa-dri libglapi-mesa libglvnd0
#   libglx-mesa0 libglx0 libgme0 libgomp1 libgraphite2-3 libgsm1 libharfbuzz0b
#   libiec61883-0 libigdgmm11 libjack-jackd2-0 libjbig0 libjpeg-turbo8 libjpeg8
#   liblilv-0-0 libllvm12 libmp3lame0 libmpg123-0 libmysofa1 libnorm1
#   libopenal-data libopenal1 libopenjp2-7 libopenmpt0 libopus0 libpango-1.0-0
#   libpangocairo-1.0-0 libpangoft2-1.0-0 libpciaccess0 libpgm-5.2-0
#   libpixman-1-0 libpostproc55 libpulse0 libraw1394-11 librsvg2-2
#   librsvg2-common librubberband2 libsamplerate0 libsdl2-2.0-0
#   libsensors-config libsensors5 libserd-0-0 libshine3 libsnappy1v5 libsndfile1
#   libsndio7.0 libsord-0-0 libsoxr0 libspeex1 libsratom-0-0 libssh-gcrypt-4
#   libswresample3 libswscale5 libthai-data libthai0 libtheora0 libtiff5
#   libtwolame0 libva-drm2 libva-x11-2 libva2 libvdpau1 libvidstab1.1
#   libvorbisenc2 libvpx6 libvulkan1 libwavpack1 libwayland-client0
#   libwayland-cursor0 libwayland-egl1 libwebp6 libwebpmux3 libx11-xcb1
#   libx264-155 libx265-179 libxcb-dri2-0 libxcb-dri3-0 libxcb-glx0
#   libxcb-present0 libxcb-randr0 libxcb-render0 libxcb-shape0 libxcb-shm0
#   libxcb-sync1 libxcb-xfixes0 libxcursor1 libxfixes3 libxi6 libxinerama1
#   libxkbcommon0 libxrandr2 libxrender1 libxshmfence1 libxss1 libxv1
#   libxvidcore4 libxxf86vm1 libzmq5 libzvbi-common libzvbi0 mesa-va-drivers
#   mesa-vdpau-drivers mesa-vulkan-drivers ocl-icd-libopencl1 va-driver-all
#   vdpau-driver-all x11-common
# Suggested packages:
#   ffmpeg-doc i965-va-driver-shaders libbluray-bdj libfftw3-bin libfftw3-dev
#   jackd2 libportaudio2 opus-tools pulseaudio libraw1394-doc librsvg2-bin
#   lm-sensors serdi sndiod sordi speex opencl-icd libvdpau-va-gl1
#   nvidia-vdpau-driver nvidia-legacy-340xx-vdpau-driver
#   nvidia-legacy-304xx-vdpau-driver
# The following NEW packages will be installed:
#   ffmpeg fontconfig fontconfig-config fonts-dejavu-core i965-va-driver
#   intel-media-va-driver libaacs0 libaom0 libass9 libasyncns0 libavc1394-0
#   libavcodec58 libavdevice58 libavfilter7 libavformat58 libavresample4
#   libavutil56 libbdplus0 libbluray2 libbs2b0 libcaca0 libcairo-gobject2
#   libcairo2 libcdio-cdda2 libcdio-paranoia2 libcdio18 libchromaprint1
#   libcodec2-0.9 libdatrie1 libdc1394-22 libdrm-amdgpu1 libdrm-intel1
#   libdrm-nouveau2 libdrm-radeon1 libfftw3-double3 libflac8 libflite1
#   libfontconfig1 libgdk-pixbuf2.0-0 libgdk-pixbuf2.0-bin
#   libgdk-pixbuf2.0-common libgl1 libgl1-mesa-dri libglapi-mesa libglvnd0
#   libglx-mesa0 libglx0 libgme0 libgomp1 libgraphite2-3 libgsm1 libharfbuzz0b
#   libiec61883-0 libigdgmm11 libjack-jackd2-0 libjbig0 libjpeg-turbo8 libjpeg8
#   liblilv-0-0 libllvm12 libmp3lame0 libmpg123-0 libmysofa1 libnorm1
#   libopenal-data libopenal1 libopenjp2-7 libopenmpt0 libopus0 libpango-1.0-0
#   libpangocairo-1.0-0 libpangoft2-1.0-0 libpciaccess0 libpgm-5.2-0
#   libpixman-1-0 libpostproc55 libpulse0 libraw1394-11 librsvg2-2
#   librsvg2-common librubberband2 libsamplerate0 libsdl2-2.0-0
#   libsensors-config libsensors5 libserd-0-0 libshine3 libsnappy1v5 libsndfile1
#   libsndio7.0 libsord-0-0 libsoxr0 libspeex1 libsratom-0-0 libssh-gcrypt-4
#   libswresample3 libswscale5 libthai-data libthai0 libtheora0 libtiff5
#   libtwolame0 libva-drm2 libva-x11-2 libva2 libvdpau1 libvidstab1.1
#   libvorbisenc2 libvpx6 libvulkan1 libwavpack1 libwayland-client0
#   libwayland-cursor0 libwayland-egl1 libwebp6 libwebpmux3 libx11-xcb1
#   libx264-155 libx265-179 libxcb-dri2-0 libxcb-dri3-0 libxcb-glx0
#   libxcb-present0 libxcb-randr0 libxcb-render0 libxcb-shape0 libxcb-shm0
#   libxcb-sync1 libxcb-xfixes0 libxcursor1 libxfixes3 libxi6 libxinerama1
#   libxkbcommon0 libxrandr2 libxrender1 libxshmfence1 libxss1 libxv1
#   libxvidcore4 libxxf86vm1 libzmq5 libzvbi-common libzvbi0 mesa-va-drivers
#   mesa-vdpau-drivers mesa-vulkan-drivers ocl-icd-libopencl1 va-driver-all
#   vdpau-driver-all x11-common
# 0 upgraded, 151 newly installed, 0 to remove and 183 not upgraded.
# Need to get 92.9 MB of archives.
# After this operation, 768 MB of additional disk space will be used.
# Do you want to continue? [Y/n] Abort.
# Changelog.md
# LICENSE
# Readme.md
# configure.ipynb
# fabric_examples
# requirements.txt
# start_here.ipynb
# Changelog.md
# LICENSE
# Readme.md
# configure.ipynb
# fabric_examples
# requirements.txt
# start_here.ipynb
#
#
# ens3: flags=4163<UP,BROADCAST,RUNNING,MULTICAST>  mtu 9000
# ens3: flags=4163<UP,BROADCAST,RUNNING,MULTICAST>  mtu 9000
#
#
# Node:
#    Name              : s3
# Reading package lists...
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# Building dependency tree...
# Reading state information...
# The following NEW packages will be installed:
#   net-tools
# 0 upgraded, 1 newly installed, 0 to remove and 183 not upgraded.
# Need to get 196 kB of archives.
# After this operation, 864 kB of additional disk space will be used.
# Get:1 http://nova.clouds.archive.ubuntu.com/ubuntu focal/main amd64 net-tools amd64 1.60+git20180626.aebd88e-1ubuntu1 [196 kB]
#  debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
#   debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
#  Fetched 196 kB in 1s (191 kB/s)
# Selecting previously unselected package net-tools.
# (Reading database ... 63577 files and directories currently installed.)
# Preparing to unpack .../net-tools_1.60+git20180626.aebd88e-1ubuntu1_amd64.deb ...
# Unpacking net-tools (1.60+git20180626.aebd88e-1ubuntu1) ...
# Setting up net-tools (1.60+git20180626.aebd88e-1ubuntu1) ...
# Processing triggers for man-db (2.9.1-1) ...
#  Cloning into 'jupyter-examples'...
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#  Reading package lists...
# Building dependency tree...
# Reading state information...
# The following additional packages will be installed:
#   fontconfig fontconfig-config fonts-dejavu-core i965-va-driver
#   intel-media-va-driver libaacs0 libaom0 libass9 libasyncns0 libavc1394-0
#   libavcodec58 libavdevice58 libavfilter7 libavformat58 libavresample4
#   libavutil56 libbdplus0 libbluray2 libbs2b0 libcaca0 libcairo-gobject2
#   libcairo2 libcdio-cdda2 libcdio-paranoia2 libcdio18 libchromaprint1
#   libcodec2-0.9 libdatrie1 libdc1394-22 libdrm-amdgpu1 libdrm-intel1
#   libdrm-nouveau2 libdrm-radeon1 libfftw3-double3 libflac8 libflite1
#   libfontconfig1 libgdk-pixbuf2.0-0 libgdk-pixbuf2.0-bin
#   libgdk-pixbuf2.0-common libgl1 libgl1-mesa-dri libglapi-mesa libglvnd0
#   libglx-mesa0 libglx0 libgme0 libgomp1 libgraphite2-3 libgsm1 libharfbuzz0b
#   libiec61883-0 libigdgmm11 libjack-jackd2-0 libjbig0 libjpeg-turbo8 libjpeg8
#   liblilv-0-0 libllvm12 libmp3lame0 libmpg123-0 libmysofa1 libnorm1
#   libopenal-data libopenal1 libopenjp2-7 libopenmpt0 libopus0 libpango-1.0-0
#   libpangocairo-1.0-0 libpangoft2-1.0-0 libpciaccess0 libpgm-5.2-0
#   libpixman-1-0 libpostproc55 libpulse0 libraw1394-11 librsvg2-2
#   librsvg2-common librubberband2 libsamplerate0 libsdl2-2.0-0
#   libsensors-config libsensors5 libserd-0-0 libshine3 libsnappy1v5 libsndfile1
#   libsndio7.0 libsord-0-0 libsoxr0 libspeex1 libsratom-0-0 libssh-gcrypt-4
#   libswresample3 libswscale5 libthai-data libthai0 libtheora0 libtiff5
#   libtwolame0 libva-drm2 libva-x11-2 libva2 libvdpau1 libvidstab1.1
#   libvorbisenc2 libvpx6 libvulkan1 libwavpack1 libwayland-client0
#   libwayland-cursor0 libwayland-egl1 libwebp6 libwebpmux3 libx11-xcb1
#   libx264-155 libx265-179 libxcb-dri2-0 libxcb-dri3-0 libxcb-glx0
#   libxcb-present0 libxcb-randr0 libxcb-render0 libxcb-shape0 libxcb-shm0
#   libxcb-sync1 libxcb-xfixes0 libxcursor1 libxfixes3 libxi6 libxinerama1
#   libxkbcommon0 libxrandr2 libxrender1 libxshmfence1 libxss1 libxv1
#   libxvidcore4 libxxf86vm1 libzmq5 libzvbi-common libzvbi0 mesa-va-drivers
#   mesa-vdpau-drivers mesa-vulkan-drivers ocl-icd-libopencl1 va-driver-all
#   vdpau-driver-all x11-common
# Suggested packages:
#   ffmpeg-doc i965-va-driver-shaders libbluray-bdj libfftw3-bin libfftw3-dev
#   jackd2 libportaudio2 opus-tools pulseaudio libraw1394-doc librsvg2-bin
#   lm-sensors serdi sndiod sordi speex opencl-icd libvdpau-va-gl1
#   nvidia-vdpau-driver nvidia-legacy-340xx-vdpau-driver
#   nvidia-legacy-304xx-vdpau-driver
# The following NEW packages will be installed:
#   ffmpeg fontconfig fontconfig-config fonts-dejavu-core i965-va-driver
#   intel-media-va-driver libaacs0 libaom0 libass9 libasyncns0 libavc1394-0
#   libavcodec58 libavdevice58 libavfilter7 libavformat58 libavresample4
#   libavutil56 libbdplus0 libbluray2 libbs2b0 libcaca0 libcairo-gobject2
#   libcairo2 libcdio-cdda2 libcdio-paranoia2 libcdio18 libchromaprint1
#   libcodec2-0.9 libdatrie1 libdc1394-22 libdrm-amdgpu1 libdrm-intel1
#   libdrm-nouveau2 libdrm-radeon1 libfftw3-double3 libflac8 libflite1
#   libfontconfig1 libgdk-pixbuf2.0-0 libgdk-pixbuf2.0-bin
#   libgdk-pixbuf2.0-common libgl1 libgl1-mesa-dri libglapi-mesa libglvnd0
#   libglx-mesa0 libglx0 libgme0 libgomp1 libgraphite2-3 libgsm1 libharfbuzz0b
#   libiec61883-0 libigdgmm11 libjack-jackd2-0 libjbig0 libjpeg-turbo8 libjpeg8
#   liblilv-0-0 libllvm12 libmp3lame0 libmpg123-0 libmysofa1 libnorm1
#   libopenal-data libopenal1 libopenjp2-7 libopenmpt0 libopus0 libpango-1.0-0
#   libpangocairo-1.0-0 libpangoft2-1.0-0 libpciaccess0 libpgm-5.2-0
#   libpixman-1-0 libpostproc55 libpulse0 libraw1394-11 librsvg2-2
#   librsvg2-common librubberband2 libsamplerate0 libsdl2-2.0-0
#   libsensors-config libsensors5 libserd-0-0 libshine3 libsnappy1v5 libsndfile1
#   libsndio7.0 libsord-0-0 libsoxr0 libspeex1 libsratom-0-0 libssh-gcrypt-4
#   libswresample3 libswscale5 libthai-data libthai0 libtheora0 libtiff5
#   libtwolame0 libva-drm2 libva-x11-2 libva2 libvdpau1 libvidstab1.1
#   libvorbisenc2 libvpx6 libvulkan1 libwavpack1 libwayland-client0
#   libwayland-cursor0 libwayland-egl1 libwebp6 libwebpmux3 libx11-xcb1
#   libx264-155 libx265-179 libxcb-dri2-0 libxcb-dri3-0 libxcb-glx0
#   libxcb-present0 libxcb-randr0 libxcb-render0 libxcb-shape0 libxcb-shm0
#   libxcb-sync1 libxcb-xfixes0 libxcursor1 libxfixes3 libxi6 libxinerama1
#   libxkbcommon0 libxrandr2 libxrender1 libxshmfence1 libxss1 libxv1
#   libxvidcore4 libxxf86vm1 libzmq5 libzvbi-common libzvbi0 mesa-va-drivers
#   mesa-vdpau-drivers mesa-vulkan-drivers ocl-icd-libopencl1 va-driver-all
#   vdpau-driver-all x11-common
# 0 upgraded, 151 newly installed, 0 to remove and 183 not upgraded.
# Need to get 92.9 MB of archives.
# After this operation, 768 MB of additional disk space will be used.
# Do you want to continue? [Y/n] Abort.
# Changelog.md
# LICENSE
# Readme.md
# configure.ipynb
# fabric_examples
# requirements.txt
# start_here.ipynb
# Changelog.md
# LICENSE
# Readme.md
# configure.ipynb
# fabric_examples
# requirements.txt
# start_here.ipynb
#
#
# ens3: flags=4163<UP,BROADCAST,RUNNING,MULTICAST>  mtu 9000
# ens3: flags=4163<UP,BROADCAST,RUNNING,MULTICAST>  mtu 9000
#
#
# Node:
#    Name              : h1
# Reading package lists...
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# Building dependency tree...
# Reading state information...
# The following NEW packages will be installed:
#   net-tools
# 0 upgraded, 1 newly installed, 0 to remove and 183 not upgraded.
# Need to get 196 kB of archives.
# After this operation, 864 kB of additional disk space will be used.
# Get:1 http://nova.clouds.archive.ubuntu.com/ubuntu focal/main amd64 net-tools amd64 1.60+git20180626.aebd88e-1ubuntu1 [196 kB]
#  debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
#   debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
#   dpkg-preconfigure: unable to re-open stdin:
#  Fetched 196 kB in 1s (225 kB/s)
# Selecting previously unselected package net-tools.
# (Reading database ... 63577 files and directories currently installed.)
# Preparing to unpack .../net-tools_1.60+git20180626.aebd88e-1ubuntu1_amd64.deb ...
# Unpacking net-tools (1.60+git20180626.aebd88e-1ubuntu1) ...
# Setting up net-tools (1.60+git20180626.aebd88e-1ubuntu1) ...
# Processing triggers for man-db (2.9.1-1) ...
#  Cloning into 'jupyter-examples'...
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#  Reading package lists...
# Building dependency tree...
# Reading state information...
# The following additional packages will be installed:
#   fontconfig fontconfig-config fonts-dejavu-core i965-va-driver
#   intel-media-va-driver libaacs0 libaom0 libass9 libasyncns0 libavc1394-0
#   libavcodec58 libavdevice58 libavfilter7 libavformat58 libavresample4
#   libavutil56 libbdplus0 libbluray2 libbs2b0 libcaca0 libcairo-gobject2
#   libcairo2 libcdio-cdda2 libcdio-paranoia2 libcdio18 libchromaprint1
#   libcodec2-0.9 libdatrie1 libdc1394-22 libdrm-amdgpu1 libdrm-intel1
#   libdrm-nouveau2 libdrm-radeon1 libfftw3-double3 libflac8 libflite1
#   libfontconfig1 libgdk-pixbuf2.0-0 libgdk-pixbuf2.0-bin
#   libgdk-pixbuf2.0-common libgl1 libgl1-mesa-dri libglapi-mesa libglvnd0
#   libglx-mesa0 libglx0 libgme0 libgomp1 libgraphite2-3 libgsm1 libharfbuzz0b
#   libiec61883-0 libigdgmm11 libjack-jackd2-0 libjbig0 libjpeg-turbo8 libjpeg8
#   liblilv-0-0 libllvm12 libmp3lame0 libmpg123-0 libmysofa1 libnorm1
#   libopenal-data libopenal1 libopenjp2-7 libopenmpt0 libopus0 libpango-1.0-0
#   libpangocairo-1.0-0 libpangoft2-1.0-0 libpciaccess0 libpgm-5.2-0
#   libpixman-1-0 libpostproc55 libpulse0 libraw1394-11 librsvg2-2
#   librsvg2-common librubberband2 libsamplerate0 libsdl2-2.0-0
#   libsensors-config libsensors5 libserd-0-0 libshine3 libsnappy1v5 libsndfile1
#   libsndio7.0 libsord-0-0 libsoxr0 libspeex1 libsratom-0-0 libssh-gcrypt-4
#   libswresample3 libswscale5 libthai-data libthai0 libtheora0 libtiff5
#   libtwolame0 libva-drm2 libva-x11-2 libva2 libvdpau1 libvidstab1.1
#   libvorbisenc2 libvpx6 libvulkan1 libwavpack1 libwayland-client0
#   libwayland-cursor0 libwayland-egl1 libwebp6 libwebpmux3 libx11-xcb1
#   libx264-155 libx265-179 libxcb-dri2-0 libxcb-dri3-0 libxcb-glx0
#   libxcb-present0 libxcb-randr0 libxcb-render0 libxcb-shape0 libxcb-shm0
#   libxcb-sync1 libxcb-xfixes0 libxcursor1 libxfixes3 libxi6 libxinerama1
#   libxkbcommon0 libxrandr2 libxrender1 libxshmfence1 libxss1 libxv1
#   libxvidcore4 libxxf86vm1 libzmq5 libzvbi-common libzvbi0 mesa-va-drivers
#   mesa-vdpau-drivers mesa-vulkan-drivers ocl-icd-libopencl1 va-driver-all
#   vdpau-driver-all x11-common
# Suggested packages:
#   ffmpeg-doc i965-va-driver-shaders libbluray-bdj libfftw3-bin libfftw3-dev
#   jackd2 libportaudio2 opus-tools pulseaudio libraw1394-doc librsvg2-bin
#   lm-sensors serdi sndiod sordi speex opencl-icd libvdpau-va-gl1
#   nvidia-vdpau-driver nvidia-legacy-340xx-vdpau-driver
#   nvidia-legacy-304xx-vdpau-driver
# The following NEW packages will be installed:
#   ffmpeg fontconfig fontconfig-config fonts-dejavu-core i965-va-driver
#   intel-media-va-driver libaacs0 libaom0 libass9 libasyncns0 libavc1394-0
#   libavcodec58 libavdevice58 libavfilter7 libavformat58 libavresample4
#   libavutil56 libbdplus0 libbluray2 libbs2b0 libcaca0 libcairo-gobject2
#   libcairo2 libcdio-cdda2 libcdio-paranoia2 libcdio18 libchromaprint1
#   libcodec2-0.9 libdatrie1 libdc1394-22 libdrm-amdgpu1 libdrm-intel1
#   libdrm-nouveau2 libdrm-radeon1 libfftw3-double3 libflac8 libflite1
#   libfontconfig1 libgdk-pixbuf2.0-0 libgdk-pixbuf2.0-bin
#   libgdk-pixbuf2.0-common libgl1 libgl1-mesa-dri libglapi-mesa libglvnd0
#   libglx-mesa0 libglx0 libgme0 libgomp1 libgraphite2-3 libgsm1 libharfbuzz0b
#   libiec61883-0 libigdgmm11 libjack-jackd2-0 libjbig0 libjpeg-turbo8 libjpeg8
#   liblilv-0-0 libllvm12 libmp3lame0 libmpg123-0 libmysofa1 libnorm1
#   libopenal-data libopenal1 libopenjp2-7 libopenmpt0 libopus0 libpango-1.0-0
#   libpangocairo-1.0-0 libpangoft2-1.0-0 libpciaccess0 libpgm-5.2-0
#   libpixman-1-0 libpostproc55 libpulse0 libraw1394-11 librsvg2-2
#   librsvg2-common librubberband2 libsamplerate0 libsdl2-2.0-0
#   libsensors-config libsensors5 libserd-0-0 libshine3 libsnappy1v5 libsndfile1
#   libsndio7.0 libsord-0-0 libsoxr0 libspeex1 libsratom-0-0 libssh-gcrypt-4
#   libswresample3 libswscale5 libthai-data libthai0 libtheora0 libtiff5
#   libtwolame0 libva-drm2 libva-x11-2 libva2 libvdpau1 libvidstab1.1
#   libvorbisenc2 libvpx6 libvulkan1 libwavpack1 libwayland-client0
#   libwayland-cursor0 libwayland-egl1 libwebp6 libwebpmux3 libx11-xcb1
#   libx264-155 libx265-179 libxcb-dri2-0 libxcb-dri3-0 libxcb-glx0
#   libxcb-present0 libxcb-randr0 libxcb-render0 libxcb-shape0 libxcb-shm0
#   libxcb-sync1 libxcb-xfixes0 libxcursor1 libxfixes3 libxi6 libxinerama1
#   libxkbcommon0 libxrandr2 libxrender1 libxshmfence1 libxss1 libxv1
#   libxvidcore4 libxxf86vm1 libzmq5 libzvbi-common libzvbi0 mesa-va-drivers
#   mesa-vdpau-drivers mesa-vulkan-drivers ocl-icd-libopencl1 va-driver-all
#   vdpau-driver-all x11-common
# 0 upgraded, 151 newly installed, 0 to remove and 183 not upgraded.
# Need to get 92.9 MB of archives.
# After this operation, 768 MB of additional disk space will be used.
# Do you want to continue? [Y/n] Abort.
# Changelog.md
# LICENSE
# Readme.md
# configure.ipynb
# fabric_examples
# requirements.txt
# start_here.ipynb
# Changelog.md
# LICENSE
# Readme.md
# configure.ipynb
# fabric_examples
# requirements.txt
# start_here.ipynb
#
#
# ens3: flags=4163<UP,BROADCAST,RUNNING,MULTICAST>  mtu 9000
# ens3: flags=4163<UP,BROADCAST,RUNNING,MULTICAST>  mtu 9000
#
#
# Node:
#    Name              : h11
# Reading package lists...
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# Building dependency tree...
# Reading state information...
# The following NEW packages will be installed:
#   net-tools
# 0 upgraded, 1 newly installed, 0 to remove and 183 not upgraded.
# Need to get 196 kB of archives.
# After this operation, 864 kB of additional disk space will be used.
# Get:1 http://nova.clouds.archive.ubuntu.com/ubuntu focal/main amd64 net-tools amd64 1.60+git20180626.aebd88e-1ubuntu1 [196 kB]
#  debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
#   debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
#   dpkg-preconfigure: unable to re-open stdin:
#  Fetched 196 kB in 0s (539 kB/s)
# Selecting previously unselected package net-tools.
# (Reading database ... 63577 files and directories currently installed.)
# Preparing to unpack .../net-tools_1.60+git20180626.aebd88e-1ubuntu1_amd64.deb ...
# Unpacking net-tools (1.60+git20180626.aebd88e-1ubuntu1) ...
# Setting up net-tools (1.60+git20180626.aebd88e-1ubuntu1) ...
# Processing triggers for man-db (2.9.1-1) ...
#  Cloning into 'jupyter-examples'...
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#  Reading package lists...
# Building dependency tree...
# Reading state information...
# The following additional packages will be installed:
#   fontconfig fontconfig-config fonts-dejavu-core i965-va-driver
#   intel-media-va-driver libaacs0 libaom0 libass9 libasyncns0 libavc1394-0
#   libavcodec58 libavdevice58 libavfilter7 libavformat58 libavresample4
#   libavutil56 libbdplus0 libbluray2 libbs2b0 libcaca0 libcairo-gobject2
#   libcairo2 libcdio-cdda2 libcdio-paranoia2 libcdio18 libchromaprint1
#   libcodec2-0.9 libdatrie1 libdc1394-22 libdrm-amdgpu1 libdrm-intel1
#   libdrm-nouveau2 libdrm-radeon1 libfftw3-double3 libflac8 libflite1
#   libfontconfig1 libgdk-pixbuf2.0-0 libgdk-pixbuf2.0-bin
#   libgdk-pixbuf2.0-common libgl1 libgl1-mesa-dri libglapi-mesa libglvnd0
#   libglx-mesa0 libglx0 libgme0 libgomp1 libgraphite2-3 libgsm1 libharfbuzz0b
#   libiec61883-0 libigdgmm11 libjack-jackd2-0 libjbig0 libjpeg-turbo8 libjpeg8
#   liblilv-0-0 libllvm12 libmp3lame0 libmpg123-0 libmysofa1 libnorm1
#   libopenal-data libopenal1 libopenjp2-7 libopenmpt0 libopus0 libpango-1.0-0
#   libpangocairo-1.0-0 libpangoft2-1.0-0 libpciaccess0 libpgm-5.2-0
#   libpixman-1-0 libpostproc55 libpulse0 libraw1394-11 librsvg2-2
#   librsvg2-common librubberband2 libsamplerate0 libsdl2-2.0-0
#   libsensors-config libsensors5 libserd-0-0 libshine3 libsnappy1v5 libsndfile1
#   libsndio7.0 libsord-0-0 libsoxr0 libspeex1 libsratom-0-0 libssh-gcrypt-4
#   libswresample3 libswscale5 libthai-data libthai0 libtheora0 libtiff5
#   libtwolame0 libva-drm2 libva-x11-2 libva2 libvdpau1 libvidstab1.1
#   libvorbisenc2 libvpx6 libvulkan1 libwavpack1 libwayland-client0
#   libwayland-cursor0 libwayland-egl1 libwebp6 libwebpmux3 libx11-xcb1
#   libx264-155 libx265-179 libxcb-dri2-0 libxcb-dri3-0 libxcb-glx0
#   libxcb-present0 libxcb-randr0 libxcb-render0 libxcb-shape0 libxcb-shm0
#   libxcb-sync1 libxcb-xfixes0 libxcursor1 libxfixes3 libxi6 libxinerama1
#   libxkbcommon0 libxrandr2 libxrender1 libxshmfence1 libxss1 libxv1
#   libxvidcore4 libxxf86vm1 libzmq5 libzvbi-common libzvbi0 mesa-va-drivers
#   mesa-vdpau-drivers mesa-vulkan-drivers ocl-icd-libopencl1 va-driver-all
#   vdpau-driver-all x11-common
# Suggested packages:
#   ffmpeg-doc i965-va-driver-shaders libbluray-bdj libfftw3-bin libfftw3-dev
#   jackd2 libportaudio2 opus-tools pulseaudio libraw1394-doc librsvg2-bin
#   lm-sensors serdi sndiod sordi speex opencl-icd libvdpau-va-gl1
#   nvidia-vdpau-driver nvidia-legacy-340xx-vdpau-driver
#   nvidia-legacy-304xx-vdpau-driver
# The following NEW packages will be installed:
#   ffmpeg fontconfig fontconfig-config fonts-dejavu-core i965-va-driver
#   intel-media-va-driver libaacs0 libaom0 libass9 libasyncns0 libavc1394-0
#   libavcodec58 libavdevice58 libavfilter7 libavformat58 libavresample4
#   libavutil56 libbdplus0 libbluray2 libbs2b0 libcaca0 libcairo-gobject2
#   libcairo2 libcdio-cdda2 libcdio-paranoia2 libcdio18 libchromaprint1
#   libcodec2-0.9 libdatrie1 libdc1394-22 libdrm-amdgpu1 libdrm-intel1
#   libdrm-nouveau2 libdrm-radeon1 libfftw3-double3 libflac8 libflite1
#   libfontconfig1 libgdk-pixbuf2.0-0 libgdk-pixbuf2.0-bin
#   libgdk-pixbuf2.0-common libgl1 libgl1-mesa-dri libglapi-mesa libglvnd0
#   libglx-mesa0 libglx0 libgme0 libgomp1 libgraphite2-3 libgsm1 libharfbuzz0b
#   libiec61883-0 libigdgmm11 libjack-jackd2-0 libjbig0 libjpeg-turbo8 libjpeg8
#   liblilv-0-0 libllvm12 libmp3lame0 libmpg123-0 libmysofa1 libnorm1
#   libopenal-data libopenal1 libopenjp2-7 libopenmpt0 libopus0 libpango-1.0-0
#   libpangocairo-1.0-0 libpangoft2-1.0-0 libpciaccess0 libpgm-5.2-0
#   libpixman-1-0 libpostproc55 libpulse0 libraw1394-11 librsvg2-2
#   librsvg2-common librubberband2 libsamplerate0 libsdl2-2.0-0
#   libsensors-config libsensors5 libserd-0-0 libshine3 libsnappy1v5 libsndfile1
#   libsndio7.0 libsord-0-0 libsoxr0 libspeex1 libsratom-0-0 libssh-gcrypt-4
#   libswresample3 libswscale5 libthai-data libthai0 libtheora0 libtiff5
#   libtwolame0 libva-drm2 libva-x11-2 libva2 libvdpau1 libvidstab1.1
#   libvorbisenc2 libvpx6 libvulkan1 libwavpack1 libwayland-client0
#   libwayland-cursor0 libwayland-egl1 libwebp6 libwebpmux3 libx11-xcb1
#   libx264-155 libx265-179 libxcb-dri2-0 libxcb-dri3-0 libxcb-glx0
#   libxcb-present0 libxcb-randr0 libxcb-render0 libxcb-shape0 libxcb-shm0
#   libxcb-sync1 libxcb-xfixes0 libxcursor1 libxfixes3 libxi6 libxinerama1
#   libxkbcommon0 libxrandr2 libxrender1 libxshmfence1 libxss1 libxv1
#   libxvidcore4 libxxf86vm1 libzmq5 libzvbi-common libzvbi0 mesa-va-drivers
#   mesa-vdpau-drivers mesa-vulkan-drivers ocl-icd-libopencl1 va-driver-all
#   vdpau-driver-all x11-common
# 0 upgraded, 151 newly installed, 0 to remove and 183 not upgraded.
# Need to get 92.9 MB of archives.
# After this operation, 768 MB of additional disk space will be used.
# Do you want to continue? [Y/n] Abort.
# Changelog.md
# LICENSE
# Readme.md
# configure.ipynb
# fabric_examples
# requirements.txt
# start_here.ipynb
# Changelog.md
# LICENSE
# Readme.md
# configure.ipynb
# fabric_examples
# requirements.txt
# start_here.ipynb
#
#
# ens3: flags=4163<UP,BROADCAST,RUNNING,MULTICAST>  mtu 9000
# ens3: flags=4163<UP,BROADCAST,RUNNING,MULTICAST>  mtu 9000
#
#
# Node:
#    Name              : h2
# Reading package lists...
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# Building dependency tree...
# Reading state information...
# The following NEW packages will be installed:
#   net-tools
# 0 upgraded, 1 newly installed, 0 to remove and 183 not upgraded.
# Need to get 196 kB of archives.
# After this operation, 864 kB of additional disk space will be used.
# Get:1 http://nova.clouds.archive.ubuntu.com/ubuntu focal/main amd64 net-tools amd64 1.60+git20180626.aebd88e-1ubuntu1 [196 kB]
#  debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
#   debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
#  Fetched 196 kB in 1s (191 kB/s)
# Selecting previously unselected package net-tools.
# (Reading database ... 63577 files and directories currently installed.)
# Preparing to unpack .../net-tools_1.60+git20180626.aebd88e-1ubuntu1_amd64.deb ...
# Unpacking net-tools (1.60+git20180626.aebd88e-1ubuntu1) ...
# Setting up net-tools (1.60+git20180626.aebd88e-1ubuntu1) ...
# Processing triggers for man-db (2.9.1-1) ...
#  Cloning into 'jupyter-examples'...
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#  Reading package lists...
# Building dependency tree...
# Reading state information...
# The following additional packages will be installed:
#   fontconfig fontconfig-config fonts-dejavu-core i965-va-driver
#   intel-media-va-driver libaacs0 libaom0 libass9 libasyncns0 libavc1394-0
#   libavcodec58 libavdevice58 libavfilter7 libavformat58 libavresample4
#   libavutil56 libbdplus0 libbluray2 libbs2b0 libcaca0 libcairo-gobject2
#   libcairo2 libcdio-cdda2 libcdio-paranoia2 libcdio18 libchromaprint1
#   libcodec2-0.9 libdatrie1 libdc1394-22 libdrm-amdgpu1 libdrm-intel1
#   libdrm-nouveau2 libdrm-radeon1 libfftw3-double3 libflac8 libflite1
#   libfontconfig1 libgdk-pixbuf2.0-0 libgdk-pixbuf2.0-bin
#   libgdk-pixbuf2.0-common libgl1 libgl1-mesa-dri libglapi-mesa libglvnd0
#   libglx-mesa0 libglx0 libgme0 libgomp1 libgraphite2-3 libgsm1 libharfbuzz0b
#   libiec61883-0 libigdgmm11 libjack-jackd2-0 libjbig0 libjpeg-turbo8 libjpeg8
#   liblilv-0-0 libllvm12 libmp3lame0 libmpg123-0 libmysofa1 libnorm1
#   libopenal-data libopenal1 libopenjp2-7 libopenmpt0 libopus0 libpango-1.0-0
#   libpangocairo-1.0-0 libpangoft2-1.0-0 libpciaccess0 libpgm-5.2-0
#   libpixman-1-0 libpostproc55 libpulse0 libraw1394-11 librsvg2-2
#   librsvg2-common librubberband2 libsamplerate0 libsdl2-2.0-0
#   libsensors-config libsensors5 libserd-0-0 libshine3 libsnappy1v5 libsndfile1
#   libsndio7.0 libsord-0-0 libsoxr0 libspeex1 libsratom-0-0 libssh-gcrypt-4
#   libswresample3 libswscale5 libthai-data libthai0 libtheora0 libtiff5
#   libtwolame0 libva-drm2 libva-x11-2 libva2 libvdpau1 libvidstab1.1
#   libvorbisenc2 libvpx6 libvulkan1 libwavpack1 libwayland-client0
#   libwayland-cursor0 libwayland-egl1 libwebp6 libwebpmux3 libx11-xcb1
#   libx264-155 libx265-179 libxcb-dri2-0 libxcb-dri3-0 libxcb-glx0
#   libxcb-present0 libxcb-randr0 libxcb-render0 libxcb-shape0 libxcb-shm0
#   libxcb-sync1 libxcb-xfixes0 libxcursor1 libxfixes3 libxi6 libxinerama1
#   libxkbcommon0 libxrandr2 libxrender1 libxshmfence1 libxss1 libxv1
#   libxvidcore4 libxxf86vm1 libzmq5 libzvbi-common libzvbi0 mesa-va-drivers
#   mesa-vdpau-drivers mesa-vulkan-drivers ocl-icd-libopencl1 va-driver-all
#   vdpau-driver-all x11-common
# Suggested packages:
#   ffmpeg-doc i965-va-driver-shaders libbluray-bdj libfftw3-bin libfftw3-dev
#   jackd2 libportaudio2 opus-tools pulseaudio libraw1394-doc librsvg2-bin
#   lm-sensors serdi sndiod sordi speex opencl-icd libvdpau-va-gl1
#   nvidia-vdpau-driver nvidia-legacy-340xx-vdpau-driver
#   nvidia-legacy-304xx-vdpau-driver
# The following NEW packages will be installed:
#   ffmpeg fontconfig fontconfig-config fonts-dejavu-core i965-va-driver
#   intel-media-va-driver libaacs0 libaom0 libass9 libasyncns0 libavc1394-0
#   libavcodec58 libavdevice58 libavfilter7 libavformat58 libavresample4
#   libavutil56 libbdplus0 libbluray2 libbs2b0 libcaca0 libcairo-gobject2
#   libcairo2 libcdio-cdda2 libcdio-paranoia2 libcdio18 libchromaprint1
#   libcodec2-0.9 libdatrie1 libdc1394-22 libdrm-amdgpu1 libdrm-intel1
#   libdrm-nouveau2 libdrm-radeon1 libfftw3-double3 libflac8 libflite1
#   libfontconfig1 libgdk-pixbuf2.0-0 libgdk-pixbuf2.0-bin
#   libgdk-pixbuf2.0-common libgl1 libgl1-mesa-dri libglapi-mesa libglvnd0
#   libglx-mesa0 libglx0 libgme0 libgomp1 libgraphite2-3 libgsm1 libharfbuzz0b
#   libiec61883-0 libigdgmm11 libjack-jackd2-0 libjbig0 libjpeg-turbo8 libjpeg8
#   liblilv-0-0 libllvm12 libmp3lame0 libmpg123-0 libmysofa1 libnorm1
#   libopenal-data libopenal1 libopenjp2-7 libopenmpt0 libopus0 libpango-1.0-0
#   libpangocairo-1.0-0 libpangoft2-1.0-0 libpciaccess0 libpgm-5.2-0
#   libpixman-1-0 libpostproc55 libpulse0 libraw1394-11 librsvg2-2
#   librsvg2-common librubberband2 libsamplerate0 libsdl2-2.0-0
#   libsensors-config libsensors5 libserd-0-0 libshine3 libsnappy1v5 libsndfile1
#   libsndio7.0 libsord-0-0 libsoxr0 libspeex1 libsratom-0-0 libssh-gcrypt-4
#   libswresample3 libswscale5 libthai-data libthai0 libtheora0 libtiff5
#   libtwolame0 libva-drm2 libva-x11-2 libva2 libvdpau1 libvidstab1.1
#   libvorbisenc2 libvpx6 libvulkan1 libwavpack1 libwayland-client0
#   libwayland-cursor0 libwayland-egl1 libwebp6 libwebpmux3 libx11-xcb1
#   libx264-155 libx265-179 libxcb-dri2-0 libxcb-dri3-0 libxcb-glx0
#   libxcb-present0 libxcb-randr0 libxcb-render0 libxcb-shape0 libxcb-shm0
#   libxcb-sync1 libxcb-xfixes0 libxcursor1 libxfixes3 libxi6 libxinerama1
#   libxkbcommon0 libxrandr2 libxrender1 libxshmfence1 libxss1 libxv1
#   libxvidcore4 libxxf86vm1 libzmq5 libzvbi-common libzvbi0 mesa-va-drivers
#   mesa-vdpau-drivers mesa-vulkan-drivers ocl-icd-libopencl1 va-driver-all
#   vdpau-driver-all x11-common
# 0 upgraded, 151 newly installed, 0 to remove and 183 not upgraded.
# Need to get 92.9 MB of archives.
# After this operation, 768 MB of additional disk space will be used.
# Do you want to continue? [Y/n] Abort.
# Changelog.md
# LICENSE
# Readme.md
# configure.ipynb
# fabric_examples
# requirements.txt
# start_here.ipynb
# Changelog.md
# LICENSE
# Readme.md
# configure.ipynb
# fabric_examples
# requirements.txt
# start_here.ipynb
#
#
# ens3: flags=4163<UP,BROADCAST,RUNNING,MULTICAST>  mtu 9000
# ens3: flags=4163<UP,BROADCAST,RUNNING,MULTICAST>  mtu 9000
#
#
# Node:
#    Name              : h22
# Reading package lists...
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# Building dependency tree...
# Reading state information...
# The following NEW packages will be installed:
#   net-tools
# 0 upgraded, 1 newly installed, 0 to remove and 183 not upgraded.
# Need to get 196 kB of archives.
# After this operation, 864 kB of additional disk space will be used.
# Get:1 http://nova.clouds.archive.ubuntu.com/ubuntu focal/main amd64 net-tools amd64 1.60+git20180626.aebd88e-1ubuntu1 [196 kB]
#  debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
#   debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
#  Fetched 196 kB in 0s (569 kB/s)
#  dpkg-preconfigure: unable to re-open stdin:
#  Selecting previously unselected package net-tools.
# (Reading database ... 63577 files and directories currently installed.)
# Preparing to unpack .../net-tools_1.60+git20180626.aebd88e-1ubuntu1_amd64.deb ...
# Unpacking net-tools (1.60+git20180626.aebd88e-1ubuntu1) ...
# Setting up net-tools (1.60+git20180626.aebd88e-1ubuntu1) ...
# Processing triggers for man-db (2.9.1-1) ...
#  Cloning into 'jupyter-examples'...
#
#   WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#  Reading package lists...
# Building dependency tree...
# Reading state information...
# The following additional packages will be installed:
#   fontconfig fontconfig-config fonts-dejavu-core i965-va-driver
#   intel-media-va-driver libaacs0 libaom0 libass9 libasyncns0 libavc1394-0
#   libavcodec58 libavdevice58 libavfilter7 libavformat58 libavresample4
#   libavutil56 libbdplus0 libbluray2 libbs2b0 libcaca0 libcairo-gobject2
#   libcairo2 libcdio-cdda2 libcdio-paranoia2 libcdio18 libchromaprint1
#   libcodec2-0.9 libdatrie1 libdc1394-22 libdrm-amdgpu1 libdrm-intel1
#   libdrm-nouveau2 libdrm-radeon1 libfftw3-double3 libflac8 libflite1
#   libfontconfig1 libgdk-pixbuf2.0-0 libgdk-pixbuf2.0-bin
#   libgdk-pixbuf2.0-common libgl1 libgl1-mesa-dri libglapi-mesa libglvnd0
#   libglx-mesa0 libglx0 libgme0 libgomp1 libgraphite2-3 libgsm1 libharfbuzz0b
#   libiec61883-0 libigdgmm11 libjack-jackd2-0 libjbig0 libjpeg-turbo8 libjpeg8
#   liblilv-0-0 libllvm12 libmp3lame0 libmpg123-0 libmysofa1 libnorm1
#   libopenal-data libopenal1 libopenjp2-7 libopenmpt0 libopus0 libpango-1.0-0
#   libpangocairo-1.0-0 libpangoft2-1.0-0 libpciaccess0 libpgm-5.2-0
#   libpixman-1-0 libpostproc55 libpulse0 libraw1394-11 librsvg2-2
#   librsvg2-common librubberband2 libsamplerate0 libsdl2-2.0-0
#   libsensors-config libsensors5 libserd-0-0 libshine3 libsnappy1v5 libsndfile1
#   libsndio7.0 libsord-0-0 libsoxr0 libspeex1 libsratom-0-0 libssh-gcrypt-4
#   libswresample3 libswscale5 libthai-data libthai0 libtheora0 libtiff5
#   libtwolame0 libva-drm2 libva-x11-2 libva2 libvdpau1 libvidstab1.1
#   libvorbisenc2 libvpx6 libvulkan1 libwavpack1 libwayland-client0
#   libwayland-cursor0 libwayland-egl1 libwebp6 libwebpmux3 libx11-xcb1
#   libx264-155 libx265-179 libxcb-dri2-0 libxcb-dri3-0 libxcb-glx0
#   libxcb-present0 libxcb-randr0 libxcb-render0 libxcb-shape0 libxcb-shm0
#   libxcb-sync1 libxcb-xfixes0 libxcursor1 libxfixes3 libxi6 libxinerama1
#   libxkbcommon0 libxrandr2 libxrender1 libxshmfence1 libxss1 libxv1
#   libxvidcore4 libxxf86vm1 libzmq5 libzvbi-common libzvbi0 mesa-va-drivers
#   mesa-vdpau-drivers mesa-vulkan-drivers ocl-icd-libopencl1 va-driver-all
#   vdpau-driver-all x11-common
# Suggested packages:
#   ffmpeg-doc i965-va-driver-shaders libbluray-bdj libfftw3-bin libfftw3-dev
#   jackd2 libportaudio2 opus-tools pulseaudio libraw1394-doc librsvg2-bin
#   lm-sensors serdi sndiod sordi speex opencl-icd libvdpau-va-gl1
#   nvidia-vdpau-driver nvidia-legacy-340xx-vdpau-driver
#   nvidia-legacy-304xx-vdpau-driver
# The following NEW packages will be installed:
#   ffmpeg fontconfig fontconfig-config fonts-dejavu-core i965-va-driver
#   intel-media-va-driver libaacs0 libaom0 libass9 libasyncns0 libavc1394-0
#   libavcodec58 libavdevice58 libavfilter7 libavformat58 libavresample4
#   libavutil56 libbdplus0 libbluray2 libbs2b0 libcaca0 libcairo-gobject2
#   libcairo2 libcdio-cdda2 libcdio-paranoia2 libcdio18 libchromaprint1
#   libcodec2-0.9 libdatrie1 libdc1394-22 libdrm-amdgpu1 libdrm-intel1
#   libdrm-nouveau2 libdrm-radeon1 libfftw3-double3 libflac8 libflite1
#   libfontconfig1 libgdk-pixbuf2.0-0 libgdk-pixbuf2.0-bin
#   libgdk-pixbuf2.0-common libgl1 libgl1-mesa-dri libglapi-mesa libglvnd0
#   libglx-mesa0 libglx0 libgme0 libgomp1 libgraphite2-3 libgsm1 libharfbuzz0b
#   libiec61883-0 libigdgmm11 libjack-jackd2-0 libjbig0 libjpeg-turbo8 libjpeg8
#   liblilv-0-0 libllvm12 libmp3lame0 libmpg123-0 libmysofa1 libnorm1
#   libopenal-data libopenal1 libopenjp2-7 libopenmpt0 libopus0 libpango-1.0-0
#   libpangocairo-1.0-0 libpangoft2-1.0-0 libpciaccess0 libpgm-5.2-0
#   libpixman-1-0 libpostproc55 libpulse0 libraw1394-11 librsvg2-2
#   librsvg2-common librubberband2 libsamplerate0 libsdl2-2.0-0
#   libsensors-config libsensors5 libserd-0-0 libshine3 libsnappy1v5 libsndfile1
#   libsndio7.0 libsord-0-0 libsoxr0 libspeex1 libsratom-0-0 libssh-gcrypt-4
#   libswresample3 libswscale5 libthai-data libthai0 libtheora0 libtiff5
#   libtwolame0 libva-drm2 libva-x11-2 libva2 libvdpau1 libvidstab1.1
#   libvorbisenc2 libvpx6 libvulkan1 libwavpack1 libwayland-client0
#   libwayland-cursor0 libwayland-egl1 libwebp6 libwebpmux3 libx11-xcb1
#   libx264-155 libx265-179 libxcb-dri2-0 libxcb-dri3-0 libxcb-glx0
#   libxcb-present0 libxcb-randr0 libxcb-render0 libxcb-shape0 libxcb-shm0
#   libxcb-sync1 libxcb-xfixes0 libxcursor1 libxfixes3 libxi6 libxinerama1
#   libxkbcommon0 libxrandr2 libxrender1 libxshmfence1 libxss1 libxv1
#   libxvidcore4 libxxf86vm1 libzmq5 libzvbi-common libzvbi0 mesa-va-drivers
#   mesa-vdpau-drivers mesa-vulkan-drivers ocl-icd-libopencl1 va-driver-all
#   vdpau-driver-all x11-common
# 0 upgraded, 151 newly installed, 0 to remove and 183 not upgraded.
# Need to get 92.9 MB of archives.
# After this operation, 768 MB of additional disk space will be used.
# Do you want to continue? [Y/n] Abort.
# Changelog.md
# LICENSE
# Readme.md
# configure.ipynb
# fabric_examples
# requirements.txt
# start_here.ipynb
# Changelog.md
# LICENSE
# Readme.md
# configure.ipynb
# fabric_examples
# requirements.txt
# start_here.ipynb
#
#
# ens3: flags=4163<UP,BROADCAST,RUNNING,MULTICAST>  mtu 9000
# ens3: flags=4163<UP,BROADCAST,RUNNING,MULTICAST>  mtu 9000
#
#
# Node:
#    Name              : h3
# Reading package lists...
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# Building dependency tree...
# Reading state information...
# The following NEW packages will be installed:
#   net-tools
# 0 upgraded, 1 newly installed, 0 to remove and 183 not upgraded.
# Need to get 196 kB of archives.
# After this operation, 864 kB of additional disk space will be used.
# Get:1 http://nova.clouds.archive.ubuntu.com/ubuntu focal/main amd64 net-tools amd64 1.60+git20180626.aebd88e-1ubuntu1 [196 kB]
#  debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
#   debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
#   dpkg-preconfigure: unable to re-open stdin:
#  Fetched 196 kB in 0s (541 kB/s)
# Selecting previously unselected package net-tools.
# (Reading database ... 63577 files and directories currently installed.)
# Preparing to unpack .../net-tools_1.60+git20180626.aebd88e-1ubuntu1_amd64.deb ...
# Unpacking net-tools (1.60+git20180626.aebd88e-1ubuntu1) ...
# Setting up net-tools (1.60+git20180626.aebd88e-1ubuntu1) ...
# Processing triggers for man-db (2.9.1-1) ...
#  Cloning into 'jupyter-examples'...
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#  Reading package lists...
# Building dependency tree...
# Reading state information...
# The following additional packages will be installed:
#   fontconfig fontconfig-config fonts-dejavu-core i965-va-driver
#   intel-media-va-driver libaacs0 libaom0 libass9 libasyncns0 libavc1394-0
#   libavcodec58 libavdevice58 libavfilter7 libavformat58 libavresample4
#   libavutil56 libbdplus0 libbluray2 libbs2b0 libcaca0 libcairo-gobject2
#   libcairo2 libcdio-cdda2 libcdio-paranoia2 libcdio18 libchromaprint1
#   libcodec2-0.9 libdatrie1 libdc1394-22 libdrm-amdgpu1 libdrm-intel1
#   libdrm-nouveau2 libdrm-radeon1 libfftw3-double3 libflac8 libflite1
#   libfontconfig1 libgdk-pixbuf2.0-0 libgdk-pixbuf2.0-bin
#   libgdk-pixbuf2.0-common libgl1 libgl1-mesa-dri libglapi-mesa libglvnd0
#   libglx-mesa0 libglx0 libgme0 libgomp1 libgraphite2-3 libgsm1 libharfbuzz0b
#   libiec61883-0 libigdgmm11 libjack-jackd2-0 libjbig0 libjpeg-turbo8 libjpeg8
#   liblilv-0-0 libllvm12 libmp3lame0 libmpg123-0 libmysofa1 libnorm1
#   libopenal-data libopenal1 libopenjp2-7 libopenmpt0 libopus0 libpango-1.0-0
#   libpangocairo-1.0-0 libpangoft2-1.0-0 libpciaccess0 libpgm-5.2-0
#   libpixman-1-0 libpostproc55 libpulse0 libraw1394-11 librsvg2-2
#   librsvg2-common librubberband2 libsamplerate0 libsdl2-2.0-0
#   libsensors-config libsensors5 libserd-0-0 libshine3 libsnappy1v5 libsndfile1
#   libsndio7.0 libsord-0-0 libsoxr0 libspeex1 libsratom-0-0 libssh-gcrypt-4
#   libswresample3 libswscale5 libthai-data libthai0 libtheora0 libtiff5
#   libtwolame0 libva-drm2 libva-x11-2 libva2 libvdpau1 libvidstab1.1
#   libvorbisenc2 libvpx6 libvulkan1 libwavpack1 libwayland-client0
#   libwayland-cursor0 libwayland-egl1 libwebp6 libwebpmux3 libx11-xcb1
#   libx264-155 libx265-179 libxcb-dri2-0 libxcb-dri3-0 libxcb-glx0
#   libxcb-present0 libxcb-randr0 libxcb-render0 libxcb-shape0 libxcb-shm0
#   libxcb-sync1 libxcb-xfixes0 libxcursor1 libxfixes3 libxi6 libxinerama1
#   libxkbcommon0 libxrandr2 libxrender1 libxshmfence1 libxss1 libxv1
#   libxvidcore4 libxxf86vm1 libzmq5 libzvbi-common libzvbi0 mesa-va-drivers
#   mesa-vdpau-drivers mesa-vulkan-drivers ocl-icd-libopencl1 va-driver-all
#   vdpau-driver-all x11-common
# Suggested packages:
#   ffmpeg-doc i965-va-driver-shaders libbluray-bdj libfftw3-bin libfftw3-dev
#   jackd2 libportaudio2 opus-tools pulseaudio libraw1394-doc librsvg2-bin
#   lm-sensors serdi sndiod sordi speex opencl-icd libvdpau-va-gl1
#   nvidia-vdpau-driver nvidia-legacy-340xx-vdpau-driver
#   nvidia-legacy-304xx-vdpau-driver
# The following NEW packages will be installed:
#   ffmpeg fontconfig fontconfig-config fonts-dejavu-core i965-va-driver
#   intel-media-va-driver libaacs0 libaom0 libass9 libasyncns0 libavc1394-0
#   libavcodec58 libavdevice58 libavfilter7 libavformat58 libavresample4
#   libavutil56 libbdplus0 libbluray2 libbs2b0 libcaca0 libcairo-gobject2
#   libcairo2 libcdio-cdda2 libcdio-paranoia2 libcdio18 libchromaprint1
#   libcodec2-0.9 libdatrie1 libdc1394-22 libdrm-amdgpu1 libdrm-intel1
#   libdrm-nouveau2 libdrm-radeon1 libfftw3-double3 libflac8 libflite1
#   libfontconfig1 libgdk-pixbuf2.0-0 libgdk-pixbuf2.0-bin
#   libgdk-pixbuf2.0-common libgl1 libgl1-mesa-dri libglapi-mesa libglvnd0
#   libglx-mesa0 libglx0 libgme0 libgomp1 libgraphite2-3 libgsm1 libharfbuzz0b
#   libiec61883-0 libigdgmm11 libjack-jackd2-0 libjbig0 libjpeg-turbo8 libjpeg8
#   liblilv-0-0 libllvm12 libmp3lame0 libmpg123-0 libmysofa1 libnorm1
#   libopenal-data libopenal1 libopenjp2-7 libopenmpt0 libopus0 libpango-1.0-0
#   libpangocairo-1.0-0 libpangoft2-1.0-0 libpciaccess0 libpgm-5.2-0
#   libpixman-1-0 libpostproc55 libpulse0 libraw1394-11 librsvg2-2
#   librsvg2-common librubberband2 libsamplerate0 libsdl2-2.0-0
#   libsensors-config libsensors5 libserd-0-0 libshine3 libsnappy1v5 libsndfile1
#   libsndio7.0 libsord-0-0 libsoxr0 libspeex1 libsratom-0-0 libssh-gcrypt-4
#   libswresample3 libswscale5 libthai-data libthai0 libtheora0 libtiff5
#   libtwolame0 libva-drm2 libva-x11-2 libva2 libvdpau1 libvidstab1.1
#   libvorbisenc2 libvpx6 libvulkan1 libwavpack1 libwayland-client0
#   libwayland-cursor0 libwayland-egl1 libwebp6 libwebpmux3 libx11-xcb1
#   libx264-155 libx265-179 libxcb-dri2-0 libxcb-dri3-0 libxcb-glx0
#   libxcb-present0 libxcb-randr0 libxcb-render0 libxcb-shape0 libxcb-shm0
#   libxcb-sync1 libxcb-xfixes0 libxcursor1 libxfixes3 libxi6 libxinerama1
#   libxkbcommon0 libxrandr2 libxrender1 libxshmfence1 libxss1 libxv1
#   libxvidcore4 libxxf86vm1 libzmq5 libzvbi-common libzvbi0 mesa-va-drivers
#   mesa-vdpau-drivers mesa-vulkan-drivers ocl-icd-libopencl1 va-driver-all
#   vdpau-driver-all x11-common
# 0 upgraded, 151 newly installed, 0 to remove and 183 not upgraded.
# Need to get 92.9 MB of archives.
# After this operation, 768 MB of additional disk space will be used.
# Do you want to continue? [Y/n] Abort.
# Changelog.md
# LICENSE
# Readme.md
# configure.ipynb
# fabric_examples
# requirements.txt
# start_here.ipynb
# Changelog.md
# LICENSE
# Readme.md
# configure.ipynb
# fabric_examples
# requirements.txt
# start_here.ipynb
#
#
# ens3: flags=4163<UP,BROADCAST,RUNNING,MULTICAST>  mtu 9000
# ens3: flags=4163<UP,BROADCAST,RUNNING,MULTICAST>  mtu 9000

# %% [markdown]
# ### Print Details

# %%
try:
    slice = fablib.get_slice(name=slice_name)
    for node in slice.get_nodes():
        print("----")
        print("Node:")
        print(f"   Name              : {node.get_name()}")
        print(f"   Cores             : {node.get_cores()}")
        print(f"   RAM               : {node.get_ram()}")
        print(f"   Disk              : {node.get_disk()}")
        print(f"   Reservation State : {node.get_reservation_state()}")
        ssh = node.get_ssh_command().replace("ssh -i /home/fabric/work/fabric_config/.ssh/id_rsa -J durbek_gafurov_0000000854@bastion-1.fabric-testbed.net","./connect.sh")
        print(f"   SSH Command       : {ssh}")
        for component in node.get_components():
            print(f"      Name             : {component.get_name()}")
            print(f"      Model            : {component.get_model()}")
        print(f"   Interfaces        :  ", end = " ")
        for interface in node.get_interfaces():
            print(f"       Name                : {interface.get_name()}")
            print(f"           MAC                 : {interface.get_mac()}") 
            print(interface.get_os_interface(), end =" ")
            # stdout, stderr = node.execute(f'sudo apt install -y net-tools &&  sudo ifconfig {interface.get_os_interface()} up')
    for network in slice.get_l2networks():
        print("Network:")
        print(f"    Name:            {network.get_name()}")
    # print(f"Interface Map: {slice.get_interface_map()}")
except Exception as e:
    print(f"Fail: {e}")
    traceback.print_exc()
# Out:
# ----
# Node:
#    Name              : s1
#    Cores             : 2
#    RAM               : 8
#    Disk              : 100
#    Reservation State : Active
#    SSH Command       : ssh -i /home/fabric/work/fabric_config/.ssh/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@129.114.110.79
#       Name             : s1-s1_iface_h1
#       Model            : NIC_Basic
#       Name             : s1-s1_iface_to_s3
#       Model            : NIC_Basic
#       Name             : s1-s1_iface_h11
#       Model            : NIC_Basic
#       Name             : s1-s1_iface_to_s2
#       Model            : NIC_Basic
#    Interfaces        :          Name                : s1-s1_iface_h1-p1
#            MAC                 : 2A:B7:3C:BF:5B:66
# ens10 Reading package lists...
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# Building dependency tree...
# Reading state information...
# net-tools is already the newest version (1.60+git20180626.aebd88e-1ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 183 not upgraded.
#        Name                : s1-s1_iface_to_s3-p1
#            MAC                 : 26:E1:33:6D:4F:8B
# ens8 Reading package lists...
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# Building dependency tree...
# Reading state information...
# net-tools is already the newest version (1.60+git20180626.aebd88e-1ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 183 not upgraded.
#        Name                : s1-s1_iface_h11-p1
#            MAC                 : 26:C6:B9:7D:D5:22
# ens7 Reading package lists...
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# Building dependency tree...
# Reading state information...
# net-tools is already the newest version (1.60+git20180626.aebd88e-1ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 183 not upgraded.
#        Name                : s1-s1_iface_to_s2-p1
#            MAC                 : 2A:95:DD:38:25:EF
# ens9 Reading package lists...
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# Building dependency tree...
# Reading state information...
# net-tools is already the newest version (1.60+git20180626.aebd88e-1ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 183 not upgraded.
# ----
# Node:
#    Name              : s2
#    Cores             : 2
#    RAM               : 8
#    Disk              : 100
#    Reservation State : Active
#    SSH Command       : ssh -i /home/fabric/work/fabric_config/.ssh/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@129.114.110.120
#       Name             : s2-s2_iface_h22
#       Model            : NIC_Basic
#       Name             : s2-s2_iface_to_s1
#       Model            : NIC_Basic
#       Name             : s2-s2_iface_h2
#       Model            : NIC_Basic
#       Name             : s2-s2_iface_to_s3
#       Model            : NIC_Basic
#    Interfaces        :          Name                : s2-s2_iface_h22-p1
#            MAC                 : 2E:7A:CC:99:81:29
# ens7 Reading package lists...
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# Building dependency tree...
# Reading state information...
# net-tools is already the newest version (1.60+git20180626.aebd88e-1ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 183 not upgraded.
#        Name                : s2-s2_iface_to_s1-p1
#            MAC                 : 32:35:D1:70:7E:1D
# ens8 Reading package lists...
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# Building dependency tree...
# Reading state information...
# net-tools is already the newest version (1.60+git20180626.aebd88e-1ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 183 not upgraded.
#        Name                : s2-s2_iface_h2-p1
#            MAC                 : 3A:AC:16:A5:F5:44
# ens10 Reading package lists...
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# Building dependency tree...
# Reading state information...
# net-tools is already the newest version (1.60+git20180626.aebd88e-1ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 183 not upgraded.
#        Name                : s2-s2_iface_to_s3-p1
#            MAC                 : 32:7C:C3:67:7A:6C
# ens9 Reading package lists...
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# Building dependency tree...
# Reading state information...
# net-tools is already the newest version (1.60+git20180626.aebd88e-1ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 183 not upgraded.
# ----
# Node:
#    Name              : s3
#    Cores             : 2
#    RAM               : 8
#    Disk              : 100
#    Reservation State : Active
#    SSH Command       : ssh -i /home/fabric/work/fabric_config/.ssh/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@129.114.110.102
#       Name             : s3-s3_iface_to_s2
#       Model            : NIC_Basic
#       Name             : s3-s3_iface_h3
#       Model            : NIC_Basic
#       Name             : s3-s3_iface_to_s1
#       Model            : NIC_Basic
#    Interfaces        :          Name                : s3-s3_iface_to_s2-p1
#            MAC                 : 3E:02:A7:B5:E1:72
# ens7 Reading package lists...
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# Building dependency tree...
# Reading state information...
# net-tools is already the newest version (1.60+git20180626.aebd88e-1ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 183 not upgraded.
#        Name                : s3-s3_iface_h3-p1
#            MAC                 : 3E:22:DC:D7:82:DE
# ens8 Reading package lists...
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# Building dependency tree...
# Reading state information...
# net-tools is already the newest version (1.60+git20180626.aebd88e-1ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 183 not upgraded.
#        Name                : s3-s3_iface_to_s1-p1
#            MAC                 : 3E:5A:26:50:40:02
# ens9 Reading package lists...
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# Building dependency tree...
# Reading state information...
# net-tools is already the newest version (1.60+git20180626.aebd88e-1ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 183 not upgraded.
# ----
# Node:
#    Name              : h1
#    Cores             : 2
#    RAM               : 8
#    Disk              : 100
#    Reservation State : Active
#    SSH Command       : ssh -i /home/fabric/work/fabric_config/.ssh/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@129.114.110.85
#       Name             : h1-h1_nic
#       Model            : NIC_Basic
#    Interfaces        :          Name                : h1-h1_nic-p1
#            MAC                 : 3E:98:DB:AC:A0:F9
# ens7 Reading package lists...
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# Building dependency tree...
# Reading state information...
# net-tools is already the newest version (1.60+git20180626.aebd88e-1ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 183 not upgraded.
# ----
# Node:
#    Name              : h11
#    Cores             : 2
#    RAM               : 8
#    Disk              : 100
#    Reservation State : Active
#    SSH Command       : ssh -i /home/fabric/work/fabric_config/.ssh/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@129.114.110.110
#       Name             : h11-h11_nic
#       Model            : NIC_Basic
#    Interfaces        :          Name                : h11-h11_nic-p1
#            MAC                 : 46:5B:BC:9B:23:72
# ens7 Reading package lists...
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# Building dependency tree...
# Reading state information...
# net-tools is already the newest version (1.60+git20180626.aebd88e-1ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 183 not upgraded.
# ----
# Node:
#    Name              : h2
#    Cores             : 2
#    RAM               : 8
#    Disk              : 100
#    Reservation State : Active
#    SSH Command       : ssh -i /home/fabric/work/fabric_config/.ssh/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@129.114.110.93
#       Name             : h2-h2_nic
#       Model            : NIC_Basic
#    Interfaces        :          Name                : h2-h2_nic-p1
#            MAC                 : 4A:36:9F:73:88:BF
# ens7 Reading package lists...
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# Building dependency tree...
# Reading state information...
# net-tools is already the newest version (1.60+git20180626.aebd88e-1ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 183 not upgraded.
# ----
# Node:
#    Name              : h22
#    Cores             : 2
#    RAM               : 8
#    Disk              : 100
#    Reservation State : Active
#    SSH Command       : ssh -i /home/fabric/work/fabric_config/.ssh/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@129.114.110.106
#       Name             : h22-h22_nic
#       Model            : NIC_Basic
#    Interfaces        :          Name                : h22-h22_nic-p1
#            MAC                 : 4A:94:51:98:CB:BE
# ens7 Reading package lists...
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# Building dependency tree...
# Reading state information...
# net-tools is already the newest version (1.60+git20180626.aebd88e-1ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 183 not upgraded.
# ----
# Node:
#    Name              : h3
#    Cores             : 2
#    RAM               : 8
#    Disk              : 100
#    Reservation State : Active
#    SSH Command       : ssh -i /home/fabric/work/fabric_config/.ssh/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@129.114.110.74
#       Name             : h3-h3_nic
#       Model            : NIC_Basic
#    Interfaces        :          Name                : h3-h3_nic-p1
#            MAC                 : 4A:DB:A2:5F:A0:53
# ens7 Reading package lists...
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# Building dependency tree...
# Reading state information...
# net-tools is already the newest version (1.60+git20180626.aebd88e-1ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 183 not upgraded.
# Network:
#     Name:            net_s1_s2
# Network:
#     Name:            net_s2_s3
# Network:
#     Name:            net_s1_s3
# Network:
#     Name:            net_h1
# Network:
#     Name:            net_h11
# Network:
#     Name:            net_h2
# Network:
#     Name:            net_h22
# Network:
#     Name:            net_h3

# %%
try:
    for node in slice.get_nodes():
        print("----")
        print("Node:")
        print(f"   Name              : {node.get_name()}")
        for component in node.get_components():
            print(f"      Name             : {component.get_name()}")
        for interface in node.get_interfaces():
            print(f"       Name                : {interface.get_name()}")
            stdout, stderr = node.execute(f'sudo apt install -y net-tools &&  sudo ifconfig {interface.get_os_interface()} up ')
except Exception as e:
    print(f"Fail: {e}")
    traceback.print_exc()
# Out:
# ----
# Node:
#    Name              : s1
#       Name             : s1-s1_iface_h1
#       Name             : s1-s1_iface_to_s3
#       Name             : s1-s1_iface_h11
#       Name             : s1-s1_iface_to_s2
#        Name                : s1-s1_iface_h1-p1
# Reading package lists...
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# Building dependency tree...
# Reading state information...
# net-tools is already the newest version (1.60+git20180626.aebd88e-1ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 183 not upgraded.
#        Name                : s1-s1_iface_to_s3-p1
# Reading package lists...
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# Building dependency tree...
# Reading state information...
# net-tools is already the newest version (1.60+git20180626.aebd88e-1ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 183 not upgraded.
#        Name                : s1-s1_iface_h11-p1
# Reading package lists...
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# Building dependency tree...
# Reading state information...
# net-tools is already the newest version (1.60+git20180626.aebd88e-1ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 183 not upgraded.
#        Name                : s1-s1_iface_to_s2-p1
# Reading package lists...
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# Building dependency tree...
# Reading state information...
# net-tools is already the newest version (1.60+git20180626.aebd88e-1ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 183 not upgraded.
# ----
# Node:
#    Name              : s2
#       Name             : s2-s2_iface_h22
#       Name             : s2-s2_iface_to_s1
#       Name             : s2-s2_iface_h2
#       Name             : s2-s2_iface_to_s3
#        Name                : s2-s2_iface_h22-p1
# Reading package lists...
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# Building dependency tree...
# Reading state information...
# net-tools is already the newest version (1.60+git20180626.aebd88e-1ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 183 not upgraded.
#        Name                : s2-s2_iface_to_s1-p1
# Reading package lists...
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# Building dependency tree...
# Reading state information...
# net-tools is already the newest version (1.60+git20180626.aebd88e-1ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 183 not upgraded.
#        Name                : s2-s2_iface_h2-p1
# Reading package lists...
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# Building dependency tree...
# Reading state information...
# net-tools is already the newest version (1.60+git20180626.aebd88e-1ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 183 not upgraded.
#        Name                : s2-s2_iface_to_s3-p1
# Reading package lists...
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# Building dependency tree...
# Reading state information...
# net-tools is already the newest version (1.60+git20180626.aebd88e-1ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 183 not upgraded.
# ----
# Node:
#    Name              : s3
#       Name             : s3-s3_iface_to_s2
#       Name             : s3-s3_iface_h3
#       Name             : s3-s3_iface_to_s1
#        Name                : s3-s3_iface_to_s2-p1
# Reading package lists...
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# Building dependency tree...
# Reading state information...
# net-tools is already the newest version (1.60+git20180626.aebd88e-1ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 183 not upgraded.
#        Name                : s3-s3_iface_h3-p1
# Reading package lists...
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# Building dependency tree...
# Reading state information...
# net-tools is already the newest version (1.60+git20180626.aebd88e-1ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 183 not upgraded.
#        Name                : s3-s3_iface_to_s1-p1
# Reading package lists...
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# Building dependency tree...
# Reading state information...
# net-tools is already the newest version (1.60+git20180626.aebd88e-1ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 183 not upgraded.
# ----
# Node:
#    Name              : h1
#       Name             : h1-h1_nic
#        Name                : h1-h1_nic-p1
# Reading package lists...
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# Building dependency tree...
# Reading state information...
# net-tools is already the newest version (1.60+git20180626.aebd88e-1ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 183 not upgraded.
# ----
# Node:
#    Name              : h11
#       Name             : h11-h11_nic
#        Name                : h11-h11_nic-p1
# Reading package lists...
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# Building dependency tree...
# Reading state information...
# net-tools is already the newest version (1.60+git20180626.aebd88e-1ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 183 not upgraded.
# ----
# Node:
#    Name              : h2
#       Name             : h2-h2_nic
#        Name                : h2-h2_nic-p1
# Reading package lists...
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# Building dependency tree...
# Reading state information...
# net-tools is already the newest version (1.60+git20180626.aebd88e-1ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 183 not upgraded.
# ----
# Node:
#    Name              : h22
#       Name             : h22-h22_nic
#        Name                : h22-h22_nic-p1
# Reading package lists...
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# Building dependency tree...
# Reading state information...
# net-tools is already the newest version (1.60+git20180626.aebd88e-1ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 183 not upgraded.
# ----
# Node:
#    Name              : h3
#       Name             : h3-h3_nic
#        Name                : h3-h3_nic-p1
# Reading package lists...
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# Building dependency tree...
# Reading state information...
# net-tools is already the newest version (1.60+git20180626.aebd88e-1ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 183 not upgraded.

# %% [markdown]
# ## Configure Nodes

# %%
config_threads = {}

# %%
host_config_script = "sudo apt-get update -qq && sudo apt-get install -qq -y python3-scapy && git clone https://github.com/Durbek-Gafur/P4-VCC.git && git clone https://github.com/p4lang/tutorials.git/" 
def addIP(name,net_name,node_addr,node_subnet):
    node = slice.get_node(name=name)        
    h1_os_iface = node.get_interface(network_name=net_name).ip_addr_add(addr=node_addr, subnet=node_subnet)
    config_thread = node.execute_thread(host_config_script)
    config_threads[node]=config_thread
    return node
    
try:
    
    h1 = addIP(h1_name,net_h1_name,h1_addr,h1_subnet)
    # print(h1.execute(f'sudo arp -i ens7 -s 10.0.1.0 08:00:00:00:01:00 && arp -a'))
    h11 = addIP(h11_name,net_h11_name,h11_addr,h1_subnet)
    # print(h11.execute(f'sudo arp -i ens7 -s 10.0.1.10 08:00:00:00:01:00 && arp -a'))
    h2 = addIP(h2_name,net_h2_name,h2_addr,h2_subnet)
    # print(h2.execute(f'sudo arp -i ens7 -s 10.0.2.3 08:00:00:00:02:00 && arp -a'))
    h22 = addIP(h22_name,net_h22_name,h22_addr,h2_subnet)
    # print(h22.execute(f'sudo arp -i ens7 -s 10.0.2.23 08:00:00:00:02:00 && arp -a'))


except Exception as e:
    print(f"Error: {e}")
    traceback.print_exc()

# %%
def checkIP(node):
    try:        
        stdout, stderr = node.execute(f'ifconfig | grep "inet 10.0."')
        print(stdout)
        print(stderr)
    except Exception as e:
        print(f"Exception: {e}")

# %%
try: 
    for node, thread in config_threads.items():
        stdout, stderr = thread.result()
        print(f"Config thread node {node.get_name()} complete")
        checkIP(node)
        # print(f"stdout: {stdout}")
        # print(f"stderr: {stderr}")
except Exception as e:
    print(f"Error: {e}")
    traceback.print_exc() 
config_threads = {}
# Out:
# Config thread node h1 complete
#         inet 10.0.1.1  netmask 255.255.0.0  broadcast 0.0.0.0
#         inet 10.0.1.1  netmask 255.255.0.0  broadcast 0.0.0.0
#
#
# Config thread node h11 complete
#         inet 10.0.1.11  netmask 255.255.0.0  broadcast 0.0.0.0
#         inet 10.0.1.11  netmask 255.255.0.0  broadcast 0.0.0.0
#
#
# Config thread node h2 complete
#         inet 10.0.2.2  netmask 255.255.0.0  broadcast 0.0.0.0
#         inet 10.0.2.2  netmask 255.255.0.0  broadcast 0.0.0.0
#
#
# Config thread node h22 complete
#         inet 10.0.2.22  netmask 255.255.0.0  broadcast 0.0.0.0
#         inet 10.0.2.22  netmask 255.255.0.0  broadcast 0.0.0.0

# %% [markdown]
# ## Configure Switches
#
# Use ssh to configure the ifaces on the switches. This step requires testing the interfaces to figure out which interface is connected to which network.

# %% [markdown]
# #### Setup P4 Docker

# %% [markdown]
# Below are commands to let sudo work with the global proxy.

# %%
s1 = slice.get_node(name=s1_name)
s2 = slice.get_node(name=s2_name)
s3 = slice.get_node(name=s3_name)

# %%
print(s1)
# Out:
# -----------------  -------------------------------------------------------------------------------------------------------------------------
# ID                 c894d690-fd7d-4c00-993e-a1effc655796
# Name               s1
# Cores              2
# RAM                8
# Disk               100
# Image              default_ubuntu_20
# Image Type         qcow2
# Host               tacc-w2.fabric-testbed.net
# Site               TACC
# Management IP      129.114.110.79
# Reservation State  Active
# Error Message
# SSH Command        ssh -i /home/fabric/work/fabric_config/.ssh/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@129.114.110.79
# -----------------  -------------------------------------------------------------------------------------------------------------------------

# %%
h1Mac = h1.get_interface(network_name=net_h1_name).get_mac()
h11Mac = h11.get_interface(network_name=net_h11_name).get_mac()
h2Mac = h2.get_interface(network_name=net_h2_name).get_mac()
h22Mac = h22.get_interface(network_name=net_h22_name).get_mac()

s1_net_s1_s2_Mac = s1.get_interface(network_name=net_s1_s2_name).get_mac()
s2_net_s1_s2_Mac = s2.get_interface(network_name=net_s1_s2_name).get_mac()

s1_net_s1_s3_Mac = s1.get_interface(network_name=net_s1_s3_name).get_mac()
s3_net_s1_s3_Mac = s3.get_interface(network_name=net_s1_s3_name).get_mac()

s2_net_s2_s3_Mac = s2.get_interface(network_name=net_s2_s3_name).get_mac()
s3_net_s2_s3_Mac = s3.get_interface(network_name=net_s2_s3_name).get_mac()

print(h1Mac,h11Mac,h2Mac,h22Mac)
def printToFile(text,filename):
    text_file = open(filename, "w")
    n = text_file.write(text)
    text_file.close()
s1_command = """table_clear MyIngress.ipv4_lpm 
table_add MyIngress.ipv4_lpm ipv4_forward 10.0.1.1/32 => {} 1
table_add MyIngress.ipv4_lpm ipv4_forward 10.0.1.11/32 => {} 2
table_add MyIngress.ipv4_lpm ipv4_forward 10.0.2.2/32 => {} 3
table_add MyIngress.ipv4_lpm ipv4_forward 10.0.2.22/32 => {} 4
""".format(h1Mac, h11Mac,s2_net_s1_s2_Mac,s3_net_s1_s3_Mac)
s2_command = """table_clear MyIngress.ipv4_lpm 
table_add MyIngress.ipv4_lpm ipv4_forward 10.0.1.1/32 => {} 3
table_add MyIngress.ipv4_lpm ipv4_forward 10.0.1.11/32 => {} 4
table_add MyIngress.ipv4_lpm ipv4_forward 10.0.2.2/32 => {} 1
table_add MyIngress.ipv4_lpm ipv4_forward 10.0.2.22/32 => {} 2
""".format(s1_net_s1_s2_Mac,s3_net_s2_s3_Mac,h2Mac,h22Mac)
s3_command = """table_clear MyIngress.ipv4_lpm 
table_add MyIngress.ipv4_lpm ipv4_forward 10.0.1.0/24 => {} 1
table_add MyIngress.ipv4_lpm ipv4_forward 10.0.2.0/24 => {} 2
""".format(s1_net_s1_s3_Mac,s2_net_s2_s3_Mac)
printToFile(s1_command, "./scripts/s1command.txt")
printToFile(s2_command, "./scripts/s2command.txt")
printToFile(s3_command, "./scripts/s3command.txt")
print(s1_command, "./scripts/s1command.txt")
print(s2_command, "./scripts/s2command.txt")
print(s3_command, "./scripts/s3command.txt")
# Out:
# 3E:98:DB:AC:A0:F9 46:5B:BC:9B:23:72 4A:36:9F:73:88:BF 4A:94:51:98:CB:BE
# table_clear MyIngress.ipv4_lpm
# table_add MyIngress.ipv4_lpm ipv4_forward 10.0.1.1/32 => 3E:98:DB:AC:A0:F9 1
# table_add MyIngress.ipv4_lpm ipv4_forward 10.0.1.11/32 => 46:5B:BC:9B:23:72 2
# table_add MyIngress.ipv4_lpm ipv4_forward 10.0.2.2/32 => 32:35:D1:70:7E:1D 3
# table_add MyIngress.ipv4_lpm ipv4_forward 10.0.2.22/32 => 3E:5A:26:50:40:02 4
#  ./scripts/s1command.txt
# table_clear MyIngress.ipv4_lpm
# table_add MyIngress.ipv4_lpm ipv4_forward 10.0.1.1/32 => 2A:95:DD:38:25:EF 3
# table_add MyIngress.ipv4_lpm ipv4_forward 10.0.1.11/32 => 3E:02:A7:B5:E1:72 4
# table_add MyIngress.ipv4_lpm ipv4_forward 10.0.2.2/32 => 4A:36:9F:73:88:BF 1
# table_add MyIngress.ipv4_lpm ipv4_forward 10.0.2.22/32 => 4A:94:51:98:CB:BE 2
#  ./scripts/s2command.txt
# table_clear MyIngress.ipv4_lpm
# table_add MyIngress.ipv4_lpm ipv4_forward 10.0.1.0/24 => 26:E1:33:6D:4F:8B 1
# table_add MyIngress.ipv4_lpm ipv4_forward 10.0.2.0/24 => 32:7C:C3:67:7A:6C 2
#  ./scripts/s3command.txt

# %%
s1_net_s1_h1_Mac = s1.get_interface(network_name=net_h1_name).get_mac()
print(s1.get_interface(network_name=net_h1_name))
s1_net_s1_h11_Mac = s1.get_interface(network_name=net_h11_name).get_mac()
print(s1.get_interface(network_name=net_h11_name))
h1_arpcommand = """sudo arp -i ens7 -s 10.0.2.2 {} && arp -a""".format(s1_net_s1_h1_Mac)
h11_arpcommand = """sudo arp -i ens7 -s 10.0.2.22 {} && arp -a""".format(s1_net_s1_h11_Mac)
print(h1_arpcommand, "./scripts/s1_arpcommand.txt")
print(h11_arpcommand, "./scripts/s2_arpcommand.txt")
stdout, stderr = h1.execute(h1_arpcommand)
print(stdout)
print(stderr)
stdout, stderr = h11.execute(h11_arpcommand)
print(stdout)
print(stderr)
# printToFile(h1_arpcommand, "./scripts/s1_arpcommand.txt")
# printToFile(h11_arpcommand, "./scripts/s2_arpcommand.txt")
# print(h1_arpcommand, "./scripts/s1_arpcommand.txt")
# print(h11_arpcommand, "./scripts/s2_arpcommand.txt")
# Out:
# ---------------  -----------------
# Name             s1-s1_iface_h1-p1
# Network          net_h1
# Bandwidth        100
# VLAN
# MAC              2A:B7:3C:BF:5B:66
# Physical Device  ens10
# Device           ens10
# ---------------  -----------------
# ---------------  ------------------
# Name             s1-s1_iface_h11-p1
# Network          net_h11
# Bandwidth        100
# VLAN
# MAC              26:C6:B9:7D:D5:22
# Physical Device  ens7
# Device           ens7
# ---------------  ------------------
# sudo arp -i ens7 -s 10.0.2.2 2A:B7:3C:BF:5B:66 && arp -a ./scripts/s1_arpcommand.txt
# sudo arp -i ens7 -s 10.0.2.22 26:C6:B9:7D:D5:22 && arp -a ./scripts/s2_arpcommand.txt
# ? (10.20.4.11) at fa:16:3e:cc:48:d2 [ether] on ens3
# _gateway (10.20.4.1) at fa:16:3e:bc:de:76 [ether] on ens3
# ? (10.0.2.2) at 2a:b7:3c:bf:5b:66 [ether] PERM on ens7
# ? (10.20.4.11) at fa:16:3e:cc:48:d2 [ether] on ens3
# _gateway (10.20.4.1) at fa:16:3e:bc:de:76 [ether] on ens3
# ? (10.0.2.2) at 2a:b7:3c:bf:5b:66 [ether] PERM on ens7
#
#
# ? (10.0.2.22) at 26:c6:b9:7d:d5:22 [ether] PERM on ens7
# ? (10.20.4.11) at fa:16:3e:cc:48:d2 [ether] on ens3
# _gateway (10.20.4.1) at fa:16:3e:bc:de:76 [ether] on ens3
# ? (10.0.2.22) at 26:c6:b9:7d:d5:22 [ether] PERM on ens7
# ? (10.20.4.11) at fa:16:3e:cc:48:d2 [ether] on ens3
# _gateway (10.20.4.1) at fa:16:3e:bc:de:76 [ether] on ens3

# %%
def configureSwitch(name,network_names):
    try:
        node = slice.get_node(name=name)
        os_ifaces = ""
        for net_name in network_names:
            iface = node.get_interface(network_name=net_name).get_os_interface()
            if iface is None:
                print("iface is none")
                return
            os_ifaces=os_ifaces+iface+" "

        file_attributes = node.upload_file('./scripts/router_setup_p4_bmv2_container.sh','router_setup_p4_bmv2_container.sh')
        command=f"chmod +x router_setup_p4_bmv2_container.sh && sudo sh -c './router_setup_p4_bmv2_container.sh {os_ifaces}  > /tmp/script.log 2>&1' && tail /tmp/script.log"
        config_threads[node] = node.execute_thread(command)
        print(command)


    except Exception as e:
        print(f"Error: {e}")
        traceback.print_exc()

# %%
configureSwitch(s1_name,[net_h1_name,net_h11_name,net_s1_s2_name,net_s1_s3_name]) 
configureSwitch(s2_name,[net_h2_name,net_h22_name,net_s1_s2_name,net_s2_s3_name])
configureSwitch(s3_name,[net_s1_s3_name,net_s2_s3_name])
# Out:
# chmod +x router_setup_p4_bmv2_container.sh && sudo sh -c './router_setup_p4_bmv2_container.sh ens10 ens7 ens9 ens8   > /tmp/script.log 2>&1' && tail /tmp/script.log
# chmod +x router_setup_p4_bmv2_container.sh && sudo sh -c './router_setup_p4_bmv2_container.sh ens10 ens7 ens8 ens9   > /tmp/script.log 2>&1' && tail /tmp/script.log
# chmod +x router_setup_p4_bmv2_container.sh && sudo sh -c './router_setup_p4_bmv2_container.sh ens9 ens7   > /tmp/script.log 2>&1' && tail /tmp/script.log

# %%
try: 
    for node, thread in config_threads.items():
        stdout, stderr = thread.result()
        print(f"Config thread node {node.get_name()} complete")
        print(f"stdout: {stdout}")
        print(f"stderr: {stderr}")
except Exception as e:
    print(f"Error: {e}")
    traceback.print_exc()
# Out:
# Config thread node s1 complete
# stdout: V1Switch(
# MyParser(),
# MyVerifyChecksum(),
# MyIngress(),
# MyEgress(),
# MyComputeChecksum(),
# MyDeparser()
# ) main;
# simple_switch --interface 1@ens10 --interface 2@ens7 --interface 3@ens9 --interface 4@ens8 /root/tutorials/exercises/basic_tunnel/basic_tunnel.json
# done!
#
# stderr:
# Config thread node s2 complete
# stdout: V1Switch(
# MyParser(),
# MyVerifyChecksum(),
# MyIngress(),
# MyEgress(),
# MyComputeChecksum(),
# MyDeparser()
# ) main;
# simple_switch --interface 1@ens10 --interface 2@ens7 --interface 3@ens8 --interface 4@ens9 /root/tutorials/exercises/basic_tunnel/basic_tunnel.json
# done!
#
# stderr:
# Config thread node s3 complete
# stdout: V1Switch(
# MyParser(),
# MyVerifyChecksum(),
# MyIngress(),
# MyEgress(),
# MyComputeChecksum(),
# MyDeparser()
# ) main;
# simple_switch --interface 1@ens9 --interface 2@ens7 /root/tutorials/exercises/basic_tunnel/basic_tunnel.json
# done!
#
# stderr:

# %% [markdown]
# ### Confgure P4 Switch Tables
#
# Edit sX_commands.txt to change the values

# %%
s1

# %%
for switch_name in [s1_name, s2_name, s3_name]:
    switch_node = slice.get_node(name=switch_name)
    management_ip_switch = str(switch_node.get_management_ip())
    print("Swtitch Name        : {}".format(switch_node.get_name()))
    print("Management IP    : {}".format(management_ip_switch))
    
    #Configure P4 Tables
    cmd_file=f'{switch_name}command.txt'
    print(cmd_file)
    file_attributes = switch_node.upload_file(f'scripts/{cmd_file}',cmd_file)
    print("file_attributes: {}".format(file_attributes))

    stdout = switch_node.execute(f"sudo sh -c 'cat {cmd_file} | docker exec -i fabric_p4 simple_switch_CLI'")
    print("stdout: {}".format(stdout))
    stdout = switch_node.execute("echo 'sudo docker exec -it fabric_p4 /bin/bash' > dc.sh && sudo chmod +x dc.sh && ls -lh")
    print("stdout: {}".format(stdout))
# Out:
# Swtitch Name        : s1
# Management IP    : 129.114.110.79
# s1command.txt
# file_attributes: -rw-rw-r--   1 1000     1000          342 14 Jan 19:20 ?
# Obtaining JSON from switch...
# Done
# Control utility for runtime P4 table manipulation
# RuntimeCmd: RuntimeCmd: Adding entry to lpm match table MyIngress.ipv4_lpm
# match key:           LPM-0a:00:01:01/32
# action:              ipv4_forward
# runtime data:        3e:98:db:ac:a0:f9	00:01
# Entry has been added with handle 0
# RuntimeCmd: Adding entry to lpm match table MyIngress.ipv4_lpm
# match key:           LPM-0a:00:01:0b/32
# action:              ipv4_forward
# runtime data:        46:5b:bc:9b:23:72	00:02
# Entry has been added with handle 1
# RuntimeCmd: Adding entry to lpm match table MyIngress.ipv4_lpm
# match key:           LPM-0a:00:02:02/32
# action:              ipv4_forward
# runtime data:        32:35:d1:70:7e:1d	00:03
# Entry has been added with handle 2
# RuntimeCmd: Adding entry to lpm match table MyIngress.ipv4_lpm
# match key:           LPM-0a:00:02:16/32
# action:              ipv4_forward
# runtime data:        3e:5a:26:50:40:02	00:04
# Entry has been added with handle 3
# RuntimeCmd:
# stdout: ('Obtaining JSON from switch...\nDone\nControl utility for runtime P4 table manipulation\nRuntimeCmd: RuntimeCmd: Adding entry to lpm match table MyIngress.ipv4_lpm\nmatch key:           LPM-0a:00:01:01/32\naction:              ipv4_forward\nruntime data:        3e:98:db:ac:a0:f9\t00:01\nEntry has been added with handle 0\nRuntimeCmd: Adding entry to lpm match table MyIngress.ipv4_lpm\nmatch key:           LPM-0a:00:01:0b/32\naction:              ipv4_forward\nruntime data:        46:5b:bc:9b:23:72\t00:02\nEntry has been added with handle 1\nRuntimeCmd: Adding entry to lpm match table MyIngress.ipv4_lpm\nmatch key:           LPM-0a:00:02:02/32\naction:              ipv4_forward\nruntime data:        32:35:d1:70:7e:1d\t00:03\nEntry has been added with handle 2\nRuntimeCmd: Adding entry to lpm match table MyIngress.ipv4_lpm\nmatch key:           LPM-0a:00:02:16/32\naction:              ipv4_forward\nruntime data:        3e:5a:26:50:40:02\t00:04\nEntry has been added with handle 3\nRuntimeCmd: \n', '')
# total 16K
# -rwxrwxr-x 1 ubuntu ubuntu   41 Jan 14 19:20 dc.sh
# drwxrwxr-x 4 ubuntu ubuntu 4.0K Jan 14 19:07 jupyter-examples
# -rwxrwxr-x 1 ubuntu ubuntu 2.9K Jan 14 19:15 router_setup_p4_bmv2_container.sh
# -rw-rw-r-- 1 ubuntu ubuntu  342 Jan 14 19:20 s1command.txt
# stdout: ('total 16K\n-rwxrwxr-x 1 ubuntu ubuntu   41 Jan 14 19:20 dc.sh\ndrwxrwxr-x 4 ubuntu ubuntu 4.0K Jan 14 19:07 jupyter-examples\n-rwxrwxr-x 1 ubuntu ubuntu 2.9K Jan 14 19:15 router_setup_p4_bmv2_container.sh\n-rw-rw-r-- 1 ubuntu ubuntu  342 Jan 14 19:20 s1command.txt\n', '')
# Swtitch Name        : s2
# Management IP    : 129.114.110.120
# s2command.txt
# file_attributes: -rw-rw-r--   1 1000     1000          342 14 Jan 19:20 ?
# Obtaining JSON from switch...
# Done
# Control utility for runtime P4 table manipulation
# RuntimeCmd: RuntimeCmd: Adding entry to lpm match table MyIngress.ipv4_lpm
# match key:           LPM-0a:00:01:01/32
# action:              ipv4_forward
# runtime data:        2a:95:dd:38:25:ef	00:03
# Entry has been added with handle 0
# RuntimeCmd: Adding entry to lpm match table MyIngress.ipv4_lpm
# match key:           LPM-0a:00:01:0b/32
# action:              ipv4_forward
# runtime data:        3e:02:a7:b5:e1:72	00:04
# Entry has been added with handle 1
# RuntimeCmd: Adding entry to lpm match table MyIngress.ipv4_lpm
# match key:           LPM-0a:00:02:02/32
# action:              ipv4_forward
# runtime data:        4a:36:9f:73:88:bf	00:01
# Entry has been added with handle 2
# RuntimeCmd: Adding entry to lpm match table MyIngress.ipv4_lpm
# match key:           LPM-0a:00:02:16/32
# action:              ipv4_forward
# runtime data:        4a:94:51:98:cb:be	00:02
# Entry has been added with handle 3
# RuntimeCmd:
# stdout: ('Obtaining JSON from switch...\nDone\nControl utility for runtime P4 table manipulation\nRuntimeCmd: RuntimeCmd: Adding entry to lpm match table MyIngress.ipv4_lpm\nmatch key:           LPM-0a:00:01:01/32\naction:              ipv4_forward\nruntime data:        2a:95:dd:38:25:ef\t00:03\nEntry has been added with handle 0\nRuntimeCmd: Adding entry to lpm match table MyIngress.ipv4_lpm\nmatch key:           LPM-0a:00:01:0b/32\naction:              ipv4_forward\nruntime data:        3e:02:a7:b5:e1:72\t00:04\nEntry has been added with handle 1\nRuntimeCmd: Adding entry to lpm match table MyIngress.ipv4_lpm\nmatch key:           LPM-0a:00:02:02/32\naction:              ipv4_forward\nruntime data:        4a:36:9f:73:88:bf\t00:01\nEntry has been added with handle 2\nRuntimeCmd: Adding entry to lpm match table MyIngress.ipv4_lpm\nmatch key:           LPM-0a:00:02:16/32\naction:              ipv4_forward\nruntime data:        4a:94:51:98:cb:be\t00:02\nEntry has been added with handle 3\nRuntimeCmd: \n', '')
# total 16K
# -rwxrwxr-x 1 ubuntu ubuntu   41 Jan 14 19:20 dc.sh
# drwxrwxr-x 4 ubuntu ubuntu 4.0K Jan 14 19:08 jupyter-examples
# -rwxrwxr-x 1 ubuntu ubuntu 2.9K Jan 14 19:15 router_setup_p4_bmv2_container.sh
# -rw-rw-r-- 1 ubuntu ubuntu  342 Jan 14 19:20 s2command.txt
# stdout: ('total 16K\n-rwxrwxr-x 1 ubuntu ubuntu   41 Jan 14 19:20 dc.sh\ndrwxrwxr-x 4 ubuntu ubuntu 4.0K Jan 14 19:08 jupyter-examples\n-rwxrwxr-x 1 ubuntu ubuntu 2.9K Jan 14 19:15 router_setup_p4_bmv2_container.sh\n-rw-rw-r-- 1 ubuntu ubuntu  342 Jan 14 19:20 s2command.txt\n', '')
# Swtitch Name        : s3
# Management IP    : 129.114.110.102
# s3command.txt
# file_attributes: -rw-rw-r--   1 1000     1000          186 14 Jan 19:20 ?
# Obtaining JSON from switch...
# Done
# Control utility for runtime P4 table manipulation
# RuntimeCmd: RuntimeCmd: Adding entry to lpm match table MyIngress.ipv4_lpm
# match key:           LPM-0a:00:01:00/24
# action:              ipv4_forward
# runtime data:        26:e1:33:6d:4f:8b	00:01
# Entry has been added with handle 0
# RuntimeCmd: Adding entry to lpm match table MyIngress.ipv4_lpm
# match key:           LPM-0a:00:02:00/24
# action:              ipv4_forward
# runtime data:        32:7c:c3:67:7a:6c	00:02
# Entry has been added with handle 1
# RuntimeCmd:
# stdout: ('Obtaining JSON from switch...\nDone\nControl utility for runtime P4 table manipulation\nRuntimeCmd: RuntimeCmd: Adding entry to lpm match table MyIngress.ipv4_lpm\nmatch key:           LPM-0a:00:01:00/24\naction:              ipv4_forward\nruntime data:        26:e1:33:6d:4f:8b\t00:01\nEntry has been added with handle 0\nRuntimeCmd: Adding entry to lpm match table MyIngress.ipv4_lpm\nmatch key:           LPM-0a:00:02:00/24\naction:              ipv4_forward\nruntime data:        32:7c:c3:67:7a:6c\t00:02\nEntry has been added with handle 1\nRuntimeCmd: \n', '')
# total 16K
# -rwxrwxr-x 1 ubuntu ubuntu   41 Jan 14 19:20 dc.sh
# drwxrwxr-x 4 ubuntu ubuntu 4.0K Jan 14 19:08 jupyter-examples
# -rwxrwxr-x 1 ubuntu ubuntu 2.9K Jan 14 19:15 router_setup_p4_bmv2_container.sh
# -rw-rw-r-- 1 ubuntu ubuntu  186 Jan 14 19:20 s3command.txt
# stdout: ('total 16K\n-rwxrwxr-x 1 ubuntu ubuntu   41 Jan 14 19:20 dc.sh\ndrwxrwxr-x 4 ubuntu ubuntu 4.0K Jan 14 19:08 jupyter-examples\n-rwxrwxr-x 1 ubuntu ubuntu 2.9K Jan 14 19:15 router_setup_p4_bmv2_container.sh\n-rw-rw-r-- 1 ubuntu ubuntu  186 Jan 14 19:20 s3command.txt\n', '')

# %% [markdown]
# ## The switches are now configured and running. Now we are going to send packets over the switches.

# %% [markdown]
# We are going to use `send.py` and `receive.py`. We are going to re-upload them to the servers and use them. Make sure to modify the interface names in the script accordingly.

# %%
h1.upload_file('scripts/send.py', 'P4-VCC/exercises/basic_tunnel/send_modified.py')
h1.upload_file('scripts/receive.py', 'P4-VCC/exercises/basic_tunnel/receive_modified.py')
h2.upload_file('scripts/send.py', 'P4-VCC/exercises/basic_tunnel/send_modified.py')
h2.upload_file('scripts/receive.py', 'P4-VCC/exercises/basic_tunnel/receive_modified.py')
h11.upload_file('scripts/send.py', 'P4-VCC/exercises/basic_tunnel/send_modified.py')
h11.upload_file('scripts/receive.py', 'P4-VCC/exercises/basic_tunnel/receive_modified.py')
h22.upload_file('scripts/send.py', 'P4-VCC/exercises/basic_tunnel/send_modified.py')
h22.upload_file('scripts/receive.py', 'P4-VCC/exercises/basic_tunnel/receive_modified.py')
# Out:
# <SFTPAttributes: [ size=1137 uid=1000 gid=1000 mode=0o100664 atime=1673724056 mtime=1673724056 ]>

# %% [markdown]
# ## H1 sends packet, H2 recieves

# %%
h1.execute('tmux new -d \'timeout 30 watch -n 5 sudo python3 P4-VCC/exercises/basic/send_modified.py 10.0.2.2 "message100" 50\'')
print(h2.execute('sudo timeout 30 sudo python3 P4-VCC/exercises/basic/receive_modified.py')[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_156/468309975.py in <module>
# ----> 1 h1.execute('tmux new -d \'timeout 30 watch -n 5 sudo python3 P4-VCC/exercises/basic/send_modified.py 10.0.2.2 "message100" 50\'')
#       2 print(h2.execute('sudo timeout 30 sudo python3 P4-VCC/exercises/basic/receive_modified.py')[0])
#
# NameError: name 'h1' is not defined

# %%
h1.execute('sudo python3 P4-VCC/exercises/basic/send.py 10.0.2.22 "message100" 50')
# Out:
# sending on interface ens7 to 10.0.2.22
# ###[ Ethernet ]###
#   dst       = ff:ff:ff:ff:ff:ff
#   src       = 3e:98:db:ac:a0:f9
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x0
#      len       = 50
#      id        = 1
#      flags     =
#      frag      = 0
#      ttl       = 64
#      proto     = tcp
#      chksum    = 0x63af
#      src       = 10.0.1.1
#      dst       = 10.0.2.22
#      \options   \
# ###[ TCP ]###
#         sport     = 59238
#         dport     = 1234
#         seq       = 0
#         ack       = 0
#         dataofs   = 5
#         reserved  = 0
#         flags     = S
#         window    = 8192
#         chksum    = 0xb4e7
#         urgptr    = 0
#         options   = []
# ###[ Raw ]###
#            load      = 'message100'
# ("sending on interface ens7 to 10.0.2.22\n###[ Ethernet ]### \n  dst       = ff:ff:ff:ff:ff:ff\n  src       = 3e:98:db:ac:a0:f9\n  type      = IPv4\n###[ IP ]### \n     version   = 4\n     ihl       = 5\n     tos       = 0x0\n     len       = 50\n     id        = 1\n     flags     = \n     frag      = 0\n     ttl       = 64\n     proto     = tcp\n     chksum    = 0x63af\n     src       = 10.0.1.1\n     dst       = 10.0.2.22\n     \\options   \\\n###[ TCP ]### \n        sport     = 59238\n        dport     = 1234\n        seq       = 0\n        ack       = 0\n        dataofs   = 5\n        reserved  = 0\n        flags     = S\n        window    = 8192\n        chksum    = 0xb4e7\n        urgptr    = 0\n        options   = []\n###[ Raw ]### \n           load      = 'message100'\n\n",
#  '')

# %%
h11.execute('tmux new -d \'timeout 30 watch -n 5 sudo python3 P4-VCC/exercises/basic/send.py 10.0.2.22 "message100" 50\'')
print(h22.execute('sudo timeout 30 sudo python3 P4-VCC/exercises/basic/receive.py')[0])
# Out:
# sniffing on ens7
# sniffing on ens7

# %%
h1.execute('tmux new -d \'timeout 30 watch -n 5 sudo python3 P4-VCC/exercises/basic_tunnel/send_modified.py --dst_id 2 10.0.2.2 "message100"\'')
print(h2.execute('sudo timeout 30 sudo python3 P4-VCC/exercises/basic_tunnel/receive_modified.py')[0])
# Out:
# sniffing on ens7
# sniffing on ens7

# %% [markdown]
# ## H1 sends packet, H11 recieves

# %%
h1.execute('tmux new -d \'timeout 30 watch -n 5 sudo python3 P4-VCC/exercises/basic/send.py 10.0.1.11 "message100" 50\'')
print(h11.execute('sudo timeout 30 sudo python3 P4-VCC/exercises/basic/receive.py')[0])
# Out:
# sniffing on ens7
# sniffing on ens7

# %% [markdown]
# ## H2 sends packet, H1 recieves

# %%
h2.execute('tmux new -d \'timeout 30 watch -n 5 sudo python3 P4-VCC/exercises/basic/send.py 10.0.1.1 "message100" 50\'')
print(h1.execute('sudo timeout 30 sudo python3 P4-VCC/exercises/basic/receive.py')[0])
# Out:
# sniffing on ens7
# sniffing on ens7

# %% [markdown]
# ## H22 sends packet, H11 recieves

# %%
h22.execute('tmux new -d \'timeout 30 watch -n 5 sudo python3 tutorials/exercises/basic_tunnel/send_modified.py 10.0.1.11 "message100" 50\'')
print(h11.execute('sudo timeout 30 sudo python3 P4-VCC/exercises/basic/receive.py')[0])
# Out:
# sniffing on ens7
# sniffing on ens7

# %%
h1.execute('tmux new -d \'timeout 30 watch -n 5 sudo python3 P4-VCC/exercises/basic_tunnel/send_modified.py 10.0.1.11 "message100"\'')
print(h11.execute('sudo timeout 30 sudo python3 P4-VCC/exercises/basic/receive.py')[0])
# Out:
# sniffing on ens7
# sniffing on ens7

# %% [markdown]
# ## Delete Slice

# %%
# try:
#     slice = fablib.get_slice(name=slice_name)
#     slice.delete()
# except Exception as e:
#     print(f"Fail: {e}")
#     traceback.print_exc()
